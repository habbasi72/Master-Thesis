# %% [markdown]
# Class A is the typos of kind replacing letters with some random letters
# First step :
# Creating a list of random timestamp
# Extracting only Month names

# %%
import pandas as pd
import numpy as np
import random
import string
from decimal import Decimal , ROUND_HALF_UP
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Import dataset
df=pd.read_csv('Initial.csv')
df=df.drop('Unnamed: 0' , 1)
df
# Out:
#     STD_Months
# 0    September
# 1      January
# 2        April
# 3        March
# 4    September
# 5        April
# 6     December
# 7     November
# 8      January
# 9        March
# 10      August
# 11     October
# 12       April
# 13        June
# 14    November
# 15        June
# 16         May
# 17    February
# 18        July
# 19      August
# 20       April
# 21    December
# 22         May
# 23       April
# 24         May
# 25    November
# 26        June
# 27     October
# 28   September
# 29      August
# ..         ...
# 90    February
# 91     October
# 92     October
# 93        July
# 94    November
# 95    February
# 96    November
# 97       March
# 98       March
# 99     October
# 100      March
# 101   November
# 102      April
# 103       July
# 104  September
# 105       July
# 106     August
# 107  September
# 108        May
# 109  September
# 110     August
# 111       June
# 112       July
# 113    January
# 114       June
# 115   February
# ...

# %%
Values = df['STD_Months'].value_counts()
print(Values)
Values.plot.barh()
plt.show()
# Out:
# November     10
# March        10
# July         10
# December     10
# January      10
# February     10
# October      10
# April        10
# June         10
# May          10
# September    10
# August       10
# Name: STD_Months, dtype: int64

# %%
#Make a copy of initial column
df['10_Percent'] = df['STD_Months']
#Creating 10% noise
p1 = 0.1
#Extract the column's indeces [0,1,...,99]
ix1 = [(row) for row in range(df['10_Percent'].shape[0])]
for row in ix1:
    print("row:" ,row)
    indxs1 = [i for i , _ in enumerate(df['10_Percent'].iat[row])]
    print(df['10_Percent'].iat[row])
    print ('Index:',indxs1)
    length1 = len(indxs1)
    print('length:',length1)
    letters = Decimal(str(length1*p1)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions1 = random.sample(range(length1) , int(letters))
    print('positions:',positions1)
    lst1 = list(df['10_Percent'].iat[row])
    for ind1 in positions1:
        lst1[ind1]=random.choice(string.ascii_lowercase)
        df['10_Percent'].iat[row]=("".join(lst1))
    print("s:" ,df['10_Percent'].iat[row])
    print('***')
# Out:
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# positions: [0]
# s: ieptember
# ***
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# positions: [3]
# s: Janaary
# ***
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# positions: [2]
# s: Apuil
# ***
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# positions: [1]
# s: Mgrch
# ***
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# positions: [7]
# s: Septemblr
# ***
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# positions: [2]
# s: Apjil
# ***
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# positions: [4]
# s: Decetber
# ***
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# positions: [5]
# s: Novemder
# ***
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# positions: [5]
# s: Januapy
# ***
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# positions: [0]
# s: xarch
# ***
# row: 10
# August
# ...

# %%
df['20_Percent'] = df['STD_Months']
#Creating 20% noise
p2 = 0.2
ix2 = [(row) for row in range(df['20_Percent'].shape[0])]
for row in ix2:
    indxs2 = [i for i , _ in enumerate(df['20_Percent'].iat[row])]
    length2 = len(indxs2)
    letters2 = Decimal(str(length2*p2)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions2 = random.sample(range(length2) , int(letters2))
    lst2 = list(df['20_Percent'].iat[row])
    for ind2 in positions2:
        lst2[ind2]=random.choice(string.ascii_lowercase)
        df['20_Percent'].iat[row]=("".join(lst2))

# %%
df['30_Percent'] = df['STD_Months']
#Creating 30% noise
p3 = 0.3
ix3 = [(row) for row in range(df['30_Percent'].shape[0])]
for row in ix3:
    indxs3 = [i for i , _ in enumerate(df['30_Percent'].iat[row])]
    length3 = len(indxs3)
    letters3 = Decimal(str(length3*p3)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions3 = random.sample(range(length3) , int(letters3))
    lst3 = list(df['30_Percent'].iat[row])
    for ind3 in positions3:
        lst3[ind3]=random.choice(string.ascii_lowercase)
        df['30_Percent'].iat[row]=("".join(lst3))

# %%
df['40_Percent'] = df['STD_Months']
#Creating 40% noise
p4 = 0.4
ix4 = [(row) for row in range(df['40_Percent'].shape[0])]
for row in ix4:
    indxs4 = [i for i , _ in enumerate(df['40_Percent'].iat[row])]
    length4 = len(indxs4)
    letters4 = Decimal(str(length4*p4)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions4 = random.sample(range(length4) , int(letters4))
    lst4 = list(df['40_Percent'].iat[row])
    for ind4 in positions4:
        lst4[ind4]=random.choice(string.ascii_lowercase)
        df['40_Percent'].iat[row]=("".join(lst4))

# %%
df['50_Percent'] = df['STD_Months']
#Creating 50% noise
p5 = 0.5
ix5 = [(row) for row in range(df['50_Percent'].shape[0])]
for row in ix5:
    indxs5 = [i for i , _ in enumerate(df['50_Percent'].iat[row])]
    length5 = len(indxs5)
    letters5 = Decimal(str(length5*p5)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions5 = random.sample(range(length5) , int(letters5))
    lst5 = list(df['50_Percent'].iat[row])
    for ind5 in positions5:
        lst5[ind5]=random.choice(string.ascii_lowercase)
        df['50_Percent'].iat[row]=("".join(lst5))

# %%
df['60_Percent'] = df['STD_Months']
#Creating 60% noise
p6 = 0.6
ix6 = [(row) for row in range(df['60_Percent'].shape[0])]
for row in ix6:
    indxs6 = [i for i , _ in enumerate(df['60_Percent'].iat[row])]
    length6 = len(indxs6)
    letters6 = Decimal(str(length6*p6)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions6 = random.sample(range(length6) , int(letters6))
    lst6 = list(df['60_Percent'].iat[row])
    for ind6 in positions6:
        lst6[ind6]=random.choice(string.ascii_lowercase)
        df['60_Percent'].iat[row]=("".join(lst6))

# %%
df['70_Percent'] = df['STD_Months']
#Creating 70% noise
p7 = 0.7
ix7 = [(row) for row in range(df['70_Percent'].shape[0])]
for row in ix7:
    indxs7 = [i for i , _ in enumerate(df['70_Percent'].iat[row])]
    length7 = len(indxs7)
    letters7 = Decimal(str(length7*p7)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions7 = random.sample(range(length7) , int(letters7))
    lst7 = list(df['70_Percent'].iat[row])
    for ind7 in positions7:
        lst7[ind7]=random.choice(string.ascii_lowercase)
        df['70_Percent'].iat[row]=("".join(lst7))

# %%
df['80_Percent'] = df['STD_Months']
#Creating 80% noise
p8 = 0.8
ix8 = [(row) for row in range(df['80_Percent'].shape[0])]
for row in ix8:
    indxs8 = [i for i , _ in enumerate(df['80_Percent'].iat[row])]
    length8 = len(indxs8)
    letters8 = Decimal(str(length8*p8)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions8 = random.sample(range(length8) , int(letters8))
    lst8 = list(df['80_Percent'].iat[row])
    for ind8 in positions8:
        lst8[ind8]=random.choice(string.ascii_lowercase)
        df['80_Percent'].iat[row]=("".join(lst8))

# %%
df['90_Percent'] = df['STD_Months']
#Creating 90% noise
p9 = 0.9
ix9 = [(row) for row in range(df['90_Percent'].shape[0])]
for row in ix9:
    indxs9 = [i for i , _ in enumerate(df['90_Percent'].iat[row])]
    length9 = len(indxs9)
    letters9 = Decimal(str(length9*p9)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
    positions9 = random.sample(range(length9) , int(letters9))
    lst9 = list(df['90_Percent'].iat[row])
    for ind9 in positions9:
        lst9[ind9]=random.choice(string.ascii_lowercase)
        df['90_Percent'].iat[row]=("".join(lst9))

# %%
df['100_Percent'] = df['STD_Months']
#Creating 100% noise
ix10 = [(row) for row in range(df['100_Percent'].shape[0])]
for row in ix10:
    indxs10 = [i for i , _ in enumerate(df['100_Percent'].iat[row])]
    length10 = len(indxs10)
    positions10 = random.sample(range(length10) , int(length10))
    lst10 = list(df['100_Percent'].iat[row])
    for ind10 in positions10:
        lst10[ind10]=random.choice(string.ascii_lowercase)
        df['100_Percent'].iat[row]=("".join(lst10))

# %%
df
df.to_csv('A_NoisySet')
