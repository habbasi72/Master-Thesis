# %%
Class D is the typos of kind Cutting random letters

# %%
import random
from random import choice
import string
from decimal import Decimal , ROUND_HALF_UP
months = ['january' , 'february' , 'march' , 'january' , 'april']
p = [ .3 , .4]

#Replacing letters with random ascii letters
def replace(*args):
    print("Replace")
    lst = list(month)
    for ind in positions:
        lst[ind]=random.choice(string.ascii_lowercase)
        result = ("".join(lst))
    print("result:",  result)
    return result

#Cutting letters from string
def cut(*args):
    print("Cut")
    Month=month
    for ind in positions:
        Month = Month[:ind] + "-" + Month[ind+1:]
    result = Month.replace("-" , "")  
    print("result:",  result)
    return result

#Adding some random ascii letters to string
def add(*args):
    print("Add")
    Month = month
    for ind in positions:
        char = random.choice(string.ascii_letters)
        Month = Month[:ind] + char + Month[ind:]
    result = Month  
    print("result:",  result)
    return result   


for pi in p:
    print("Percentage==>" , pi)
    for month in months: 
         print("MONTH:" , month)
         length = len(month)
         print("LENGTH:" , length)
         letters = Decimal(str(length*pi)).quantize(Decimal("1") , rounding=ROUND_HALF_UP) 
         positions = random.sample(range(length) , int(letters)) 
         print("POSITIONS:" , positions)
         choice([replace , cut , add])(month , positions)
#          cut(month , positions)
#          cut(month , positions)
#          add(month , positions)
         print('\n')
    print('\n')
# Out:
# Percentage==> 0.3
# MONTH: january
# LENGTH: 7
# POSITIONS: [5, 6]
# Add
# result: januatBry
#
#
# MONTH: february
# LENGTH: 8
# POSITIONS: [6, 4]
# Cut
# result: febray
#
#
# MONTH: march
# LENGTH: 5
# POSITIONS: [3, 1]
# Replace
# result: mqrth
#
#
# MONTH: january
# LENGTH: 7
# POSITIONS: [0, 3]
# Replace
# result: yancary
#
#
# MONTH: april
# LENGTH: 5
# POSITIONS: [3, 1]
# Replace
# result: auril
#
#
#
#
# Percentage==> 0.4
# MONTH: january
# LENGTH: 7
# POSITIONS: [6, 3, 0]
# Replace
# result: ganbarr
#
#
# MONTH: february
# LENGTH: 8
# POSITIONS: [4, 5, 0]
# Replace
# result: hebrjcry
#
#
# MONTH: march
# LENGTH: 5
# POSITIONS: [1, 3]
# Add
# result: mYaCrch
#
#
# MONTH: january
# LENGTH: 7
# POSITIONS: [0, 5, 4]
# Cut
# result: anuy
#
#
# MONTH: april
# LENGTH: 5
# POSITIONS: [1, 3]
# Replace
# result: aqrbl
