# %% [markdown]
# Class B is the typos of kind Cutting random letters
# First step :
# Creating a list of random timestamp
# Extracting only Month names

# %%
import pandas as pd
import numpy as np
import random
import string
from decimal import Decimal , ROUND_HALF_UP
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Initial.csv')
df=df.drop('Unnamed: 0' , 1)
df
# Out:
#     STD_Months
# 0    September
# 1      January
# 2        April
# 3        March
# 4    September
# 5        April
# 6     December
# 7     November
# 8      January
# 9        March
# 10      August
# 11     October
# 12       April
# 13        June
# 14    November
# 15        June
# 16         May
# 17    February
# 18        July
# 19      August
# 20       April
# 21    December
# 22         May
# 23       April
# 24         May
# 25    November
# 26        June
# 27     October
# 28   September
# 29      August
# ..         ...
# 90    February
# 91     October
# 92     October
# 93        July
# 94    November
# 95    February
# 96    November
# 97       March
# 98       March
# 99     October
# 100      March
# 101   November
# 102      April
# 103       July
# 104  September
# 105       July
# 106     August
# 107  September
# 108        May
# 109  September
# 110     August
# 111       June
# 112       July
# 113    January
# 114       June
# 115   February
# 116   February
# 117  September
# 118     August
# 119    January
#
# [120 rows x 1 columns]

# %%
Values = df['STD_Months'].value_counts()
print(Values)
Values.plot.barh()
plt.show()
# Out:
# February     10
# June         10
# July         10
# December     10
# August       10
# May          10
# November     10
# March        10
# April        10
# October      10
# September    10
# January      10
# Name: STD_Months, dtype: int64

# %%
#Creating 10% to 100% noise
p = [.1 , .2 , .3 , .4 , .5 , .6 , .7 , .8 , .9 , 1]

for pi in p:    
    #Extract the column's indices [0,1,...,99]
    df[str(pi)+'_TypoC'] = ''
    ix = [(row) for row in range(df['STD_Months'].shape[0])]
    
    for row in ix:
        print("row:" ,row)
        indxs = [i for i , _ in enumerate(df['STD_Months'].iat[row])]
        
        month = df['STD_Months'].iat[row] 
        print(month)
        print ('Index:' , indxs)
        length = len(indxs)
        print('length:' , length)
        letters = Decimal(str(length*pi)).quantize(Decimal("1") , rounding=ROUND_HALF_UP)
        print('letters to Add:' , letters)
        
        if letters>0:
            positions = random.sample(range(length) , int(letters))
            print('selected positions:' , positions)
            
            for ind in positions:
                char = random.choice(string.ascii_letters)
                month = month[:ind] + char + month[ind:]
                print('lst:' , month)
                
            print('Result:' , month)
            df[str(pi)+'_TypoC'].iat[row] = month
            print('\n')
            
        else:
            print('No change!')
            df[str(pi)+'_TypoC'].iat[row] = month
            print('\n')
# Out:
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [0]
# lst: XSeptember
# Result: XSeptember
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [0]
# lst: bJanuary
# Result: bJanuary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: Apbril
# Result: Apbril
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [3]
# lst: MarLch
# Result: MarLch
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [8]
# lst: Septemberr
# Result: Septemberr
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: ApVril
# Result: ApVril
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [6]
# lst: Decembzer
# Result: Decembzer
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [5]
# lst: Novemqber
# Result: Novemqber
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: JanGuary
# Result: JanGuary
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: Mawrch
# Result: Mawrch
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [1]
# lst: Afugust
# Result: Afugust
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: Oyctober
# Result: Oyctober
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: Apritl
# Result: Apritl
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [5]
# lst: NovemLber
# Result: NovemLber
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [4]
# lst: FebrDuary
# Result: FebrDuary
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [0]
# lst: CAugust
# Result: CAugust
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: JApril
# Result: JApril
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [5]
# lst: DecemBber
# Result: DecemBber
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [1]
# lst: AOpril
# Result: AOpril
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [1]
# lst: NGovember
# Result: NGovember
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [4]
# lst: Octozber
# Result: Octozber
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [5]
# lst: SepteQmber
# Result: SepteQmber
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [4]
# lst: AuguAst
# Result: AuguAst
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: Jarnuary
# Result: Jarnuary
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [5]
# lst: Januahry
# Result: Januahry
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [7]
# lst: Novembecr
# Result: Novembecr
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [7]
# lst: Decembetr
# Result: Decembetr
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [0]
# lst: fDecember
# Result: fDecember
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [3]
# lst: DecTember
# Result: DecTember
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [6]
# lst: JanuarWy
# Result: JanuarWy
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [0]
# lst: VFebruary
# Result: VFebruary
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [4]
# lst: Novevmber
# Result: Novevmber
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [7]
# lst: SeptembIer
# Result: SeptembIer
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [5]
# lst: Augusxt
# Result: Augusxt
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [7]
# lst: Septembler
# Result: Septembler
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [1]
# lst: FBebruary
# Result: FBebruary
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [4]
# lst: DeceTmber
# Result: DeceTmber
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: OctGober
# Result: OctGober
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: ApSril
# Result: ApSril
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: CMarch
# Result: CMarch
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [6]
# lst: NovembBer
# Result: NovembBer
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [3]
# lst: AugTust
# Result: AugTust
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [1]
# lst: Smeptember
# Result: Smeptember
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [2]
# lst: FeKbruary
# Result: FeKbruary
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: mApril
# Result: mApril
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [4]
# lst: Janumary
# Result: Janumary
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [2]
# lst: AuTgust
# Result: AuTgust
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [1]
# lst: FSebruary
# Result: FSebruary
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: JanTuary
# Result: JanTuary
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [4]
# lst: Octoxber
# Result: Octoxber
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [7]
# lst: Novembemr
# Result: Novembemr
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [7]
# lst: DecembeMr
# Result: DecembeMr
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [5]
# lst: DecemOber
# Result: DecemOber
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [1]
# lst: Aqugust
# Result: Aqugust
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: Ocmtober
# Result: Ocmtober
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: MaWrch
# Result: MaWrch
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: Ocftober
# Result: Ocftober
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [6]
# lst: JanuarVy
# Result: JanuarVy
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: eMarch
# Result: eMarch
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: Maorch
# Result: Maorch
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [4]
# lst: DeceQmber
# Result: DeceQmber
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [6]
# lst: FebruaBry
# Result: FebruaBry
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: MaTrch
# Result: MaTrch
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: OcKtober
# Result: OcKtober
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [1]
# lst: AIpril
# Result: AIpril
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: HApril
# Result: HApril
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [0]
# lst: yDecember
# Result: yDecember
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [0]
# lst: MFebruary
# Result: MFebruary
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [4]
# lst: OctoNber
# Result: OctoNber
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [4]
# lst: OctoKber
# Result: OctoKber
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [7]
# lst: NovembeTr
# Result: NovembeTr
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [6]
# lst: FebruaZry
# Result: FebruaZry
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [3]
# lst: Novyember
# Result: Novyember
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: MarcVh
# Result: MarcVh
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: gMarch
# Result: gMarch
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: Ocatober
# Result: Ocatober
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: hMarch
# Result: hMarch
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [1]
# lst: Ntovember
# Result: Ntovember
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: mApril
# Result: mApril
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [1]
# lst: Sbeptember
# Result: Sbeptember
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [1]
# lst: Agugust
# Result: Agugust
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [4]
# lst: Septjember
# Result: Septjember
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 0
# No change!
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [8]
# lst: SeptembeGr
# Result: SeptembeGr
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [5]
# lst: Auguset
# Result: Auguset
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [6]
# lst: JanuarQy
# Result: JanuarQy
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 0
# No change!
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [7]
# lst: Februarxy
# Result: Februarxy
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 1
# selected positions: [4]
# lst: FebrQuary
# Result: FebrQuary
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 1
# selected positions: [0]
# lst: rSeptember
# Result: rSeptember
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [5]
# lst: Augustt
# Result: Augustt
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: JAanuary
# Result: JAanuary
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [8, 3]
# lst: SeptembeHr
# lst: SepLtembeHr
# Result: SepLtembeHr
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: Jfanuary
# Result: Jfanuary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: ApAril
# Result: ApAril
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [3]
# lst: Marach
# Result: Marach
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [5, 2]
# lst: SepteNmber
# lst: SeqpteNmber
# Result: SeqpteNmber
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: Apriel
# Result: Apriel
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 0]
# lst: Decembegr
# lst: NDecembegr
# Result: NDecembegr
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [5, 2]
# lst: Novemnber
# lst: NoEvemnber
# Result: NoEvemnber
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [0]
# lst: xJanuary
# Result: xJanuary
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [1]
# lst: MYarch
# Result: MYarch
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [4]
# lst: Augunst
# Result: Augunst
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: OcBtober
# Result: OcBtober
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [3]
# lst: AprBil
# Result: AprBil
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: zJune
# Result: zJune
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 3]
# lst: Njovember
# lst: Njowvember
# Result: Njowvember
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: tJune
# Result: tJune
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: MUay
# Result: MUay
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [5, 3]
# lst: FebruRary
# lst: FebZruRary
# Result: FebZruRary
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: JuMly
# Result: JuMly
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [2]
# lst: Aungust
# Result: Aungust
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [3]
# lst: AprKil
# Result: AprKil
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [2, 6]
# lst: Dercember
# lst: DercemVber
# Result: DercemVber
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: MCay
# Result: MCay
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: bApril
# Result: bApril
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [0]
# lst: bMay
# Result: bMay
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 4]
# lst: fNovember
# lst: fNovJember
# Result: fNovJember
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: JZune
# Result: JZune
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [4]
# lst: Octoaber
# Result: Octoaber
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [1, 2]
# lst: SJeptember
# lst: SJdeptember
# Result: SJdeptember
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [4]
# lst: Auguhst
# Result: Auguhst
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: Jaonuary
# Result: Jaonuary
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [0]
# lst: cJanuary
# Result: cJanuary
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 5]
# lst: NovEember
# lst: NovEeUmber
# Result: NovEeUmber
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [5, 3]
# lst: Decemyber
# lst: DecKemyber
# Result: DecKemyber
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 5]
# lst: DecembeRr
# lst: DecemRbeRr
# Result: DecemRbeRr
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [2, 7]
# lst: DeCcember
# lst: DeCcembQer
# Result: DeCcembQer
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: JanHuary
# Result: JanHuary
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 1]
# lst: FebLruary
# lst: FFebLruary
# Result: FFebLruary
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [2]
# lst: Mafy
# Result: Mafy
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [2]
# lst: Mawy
# Result: Mawy
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 4]
# lst: Novembder
# lst: Novekmbder
# Result: Novekmbder
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [1, 4]
# lst: SDeptember
# lst: SDepttember
# Result: SDepttember
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: lJune
# Result: lJune
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [5]
# lst: AugusYt
# Result: AugusYt
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [6, 3]
# lst: SeptemFber
# lst: SepotemFber
# Result: SepotemFber
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 5]
# lst: FXebruary
# lst: FXebrXuary
# Result: FXebrXuary
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 4]
# lst: Decembfer
# lst: DeceRmbfer
# Result: DeceRmbfer
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [0]
# lst: HOctober
# Result: HOctober
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: Msay
# Result: Msay
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: Junye
# Result: Junye
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: oJuly
# Result: oJuly
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [3]
# lst: AprYil
# Result: AprYil
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: VMarch
# Result: VMarch
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [2, 4]
# lst: NoFvember
# lst: NoFvDember
# Result: NoFvDember
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [2]
# lst: Aukgust
# Result: Aukgust
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [1, 2]
# lst: SAeptember
# lst: SABeptember
# Result: SABeptember
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: Mbay
# Result: Mbay
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: MPay
# Result: MPay
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [2, 0]
# lst: Fepbruary
# lst: WFepbruary
# Result: WFepbruary
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: nJuly
# Result: nJuly
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: ApriMl
# Result: ApriMl
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: Janiuary
# Result: Janiuary
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [4]
# lst: AuguHst
# Result: AuguHst
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 4]
# lst: Februamry
# lst: FebrTuamry
# Result: FebrTuamry
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: JanSuary
# Result: JanSuary
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: JunXe
# Result: JunXe
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: MIay
# Result: MIay
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: Octyober
# Result: Octyober
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 6]
# lst: Novpember
# lst: Novpemyber
# Result: Novpemyber
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 4]
# lst: DecembHer
# lst: DecefmbHer
# Result: DecefmbHer
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 3]
# lst: Decembder
# lst: Deccembder
# Result: Deccembder
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [2]
# lst: Auygust
# Result: Auygust
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: OctGober
# Result: OctGober
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: Maxrch
# Result: Maxrch
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [0]
# lst: OOctober
# Result: OOctober
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [3]
# lst: Janjuary
# Result: Janjuary
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: Marcth
# Result: Marcth
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: Junne
# Result: Junne
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: JuWne
# Result: JuWne
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: sMarch
# Result: sMarch
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 1]
# lst: DecembePr
# lst: DlecembePr
# Result: DlecembePr
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 5]
# lst: Febfruary
# lst: Febfrluary
# Result: Febfrluary
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: bJuly
# Result: bJuly
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: Marcbh
# Result: Marcbh
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: HJuly
# Result: HJuly
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [2]
# lst: Ocutober
# Result: Ocutober
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [1]
# lst: Awpril
# Result: Awpril
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: ApGril
# Result: ApGril
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [4, 6]
# lst: Decekmber
# lst: Decekmsber
# Result: Decekmsber
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: JulVy
# Result: JulVy
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 6]
# lst: FebruarFy
# lst: FebruaorFy
# Result: FebruaorFy
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [5]
# lst: OctobJer
# Result: OctobJer
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: OTctober
# Result: OTctober
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: pJuly
# Result: pJuly
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [2, 0]
# lst: Nodvember
# lst: LNodvember
# Result: LNodvember
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 5]
# lst: Fjebruary
# lst: Fjebreuary
# Result: Fjebreuary
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 6]
# lst: Novembezr
# lst: NovembCezr
# Result: NovembCezr
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: MarcQh
# Result: MarcQh
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [4]
# lst: Marcwh
# Result: Marcwh
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: Orctober
# Result: Orctober
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [2]
# lst: MaPrch
# Result: MaPrch
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 6]
# lst: Nkovember
# lst: NkovemHber
# Result: NkovemHber
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 1
# selected positions: [0]
# lst: wApril
# Result: wApril
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: JulIy
# Result: JulIy
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [5, 4]
# lst: Septermber
# lst: Septlermber
# Result: Septlermber
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: PJuly
# Result: PJuly
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [0]
# lst: SAugust
# Result: SAugust
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [5, 4]
# lst: Septeimber
# lst: Septueimber
# Result: Septueimber
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [2]
# lst: MaVy
# Result: MaVy
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [6, 1]
# lst: Septemcber
# lst: Szeptemcber
# Result: Szeptemcber
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [1]
# lst: ALugust
# Result: ALugust
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: Jufne
# Result: Jufne
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: zJuly
# Result: zJuly
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: JTanuary
# Result: JTanuary
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: Junse
# Result: Junse
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [4, 2]
# lst: Febrfuary
# lst: FeFbrfuary
# Result: FeFbrfuary
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 7]
# lst: kFebruary
# lst: kFebruarry
# Result: kFebruarry
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 2
# selected positions: [3, 7]
# lst: Sepytember
# lst: Sepytemyber
# Result: Sepytemyber
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 1
# selected positions: [0]
# lst: iAugust
# Result: iAugust
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 1
# selected positions: [1]
# lst: JJanuary
# Result: JJanuary
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [4, 1, 0]
# lst: SeptAember
# lst: SNeptAember
# lst: MSNeptAember
# Result: MSNeptAember
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [3, 0]
# lst: JanRuary
# lst: XJanRuary
# Result: XJanRuary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [3, 2]
# lst: Aprail
# lst: ApYrail
# Result: ApYrail
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [4, 1]
# lst: MarcDh
# lst: MoarcDh
# Result: MoarcDh
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [8, 3, 6]
# lst: SeptembeAr
# lst: SeprtembeAr
# lst: SeprteembeAr
# Result: SeprteembeAr
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [0, 4]
# lst: dApril
# lst: dApriil
# Result: dApriil
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 1]
# lst: Dechember
# lst: DQechember
# Result: DQechember
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 1]
# lst: Novwember
# lst: Ncovwember
# Result: Ncovwember
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [1, 5]
# lst: JWanuary
# lst: JWanunary
# Result: JWanunary
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [4, 2]
# lst: MarcVh
# lst: MaLrcVh
# Result: MaLrcVh
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [2, 0]
# lst: Aulgust
# lst: DAulgust
# Result: DAulgust
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [1, 6]
# lst: Otctober
# lst: OtctobMer
# Result: OtctobMer
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 4]
# lst: ADpril
# lst: ADpriil
# Result: ADpriil
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: JZune
# Result: JZune
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [5, 0]
# lst: Novemgber
# lst: tNovemgber
# Result: tNovemgber
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: JuIne
# Result: JuIne
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [0]
# lst: PMay
# Result: PMay
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 4]
# lst: FebOruary
# lst: FebOFruary
# Result: FebOFruary
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: Jmuly
# Result: Jmuly
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [0, 1]
# lst: bAugust
# lst: bQAugust
# Result: bQAugust
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [0, 4]
# lst: TApril
# lst: TAprSil
# Result: TAprSil
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 5]
# lst: Decmember
# lst: Decmedmber
# Result: Decmedmber
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: Mfay
# Result: Mfay
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [2, 0]
# lst: ApKril
# lst: IApKril
# Result: IApKril
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: Mxay
# Result: Mxay
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 6]
# lst: pNovember
# lst: pNovemiber
# Result: pNovemiber
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: JunCe
# Result: JunCe
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [6, 5]
# lst: OctobeTr
# lst: OctobyeTr
# Result: OctobyeTr
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [1, 8, 5]
# lst: SMeptember
# lst: SMeptembler
# lst: SMeptZembler
# Result: SMeptZembler
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [3, 5]
# lst: Augcust
# lst: AugcuTst
# Result: AugcuTst
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [2, 6]
# lst: JaFnuary
# lst: JaFnuadry
# Result: JaFnuadry
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [6, 5]
# lst: Januarcy
# lst: JanuaDrcy
# Result: JanuaDrcy
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [4, 5]
# lst: Novedmber
# lst: Novedember
# Result: Novedember
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 6]
# lst: sDecember
# lst: sDecemtber
# Result: sDecemtber
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 4]
# lst: eDecember
# lst: eDeclember
# Result: eDeclember
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 3]
# lst: XDecember
# lst: XDekcember
# Result: XDekcember
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [3, 0]
# lst: JanGuary
# lst: UJanGuary
# Result: UJanGuary
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 1]
# lst: RFebruary
# lst: RzFebruary
# Result: RzFebruary
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [2]
# lst: Maxy
# Result: Maxy
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [2]
# lst: Majy
# Result: Majy
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 3]
# lst: Novemberr
# lst: Novsemberr
# Result: Novsemberr
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [3, 2, 4]
# lst: Sepjtember
# lst: Segpjtember
# lst: Segpojtember
# Result: Segpojtember
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: JunFe
# Result: JunFe
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [5, 4]
# lst: Augustt
# lst: AuguFstt
# Result: AuguFstt
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [6, 1, 5]
# lst: SeptemAber
# lst: SGeptemAber
# lst: SGeptKemAber
# Result: SGeptKemAber
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [5, 2]
# lst: FebruSary
# lst: FeQbruSary
# Result: FeQbruSary
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 2]
# lst: Decsember
# lst: Deucsember
# Result: Deucsember
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [3, 5]
# lst: OctCober
# lst: OctCoNber
# Result: OctCoNber
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: MPay
# Result: MPay
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: JHune
# Result: JHune
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: JuIly
# Result: JuIly
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [2, 4]
# lst: ApGril
# lst: ApGrqil
# Result: ApGrqil
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 2]
# lst: Mwarch
# lst: Mwaarch
# Result: Mwaarch
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 2]
# lst: HNovember
# lst: HNJovember
# Result: HNJovember
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [1, 5]
# lst: Alugust
# lst: AluguHst
# Result: AluguHst
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [3, 7, 6]
# lst: Sepctember
# lst: Sepctembber
# lst: Sepcteimbber
# Result: Sepcteimbber
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [2]
# lst: Maay
# Result: Maay
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: Miay
# Result: Miay
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 4]
# lst: FebruarVy
# lst: FebrYuarVy
# Result: FebrYuarVy
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: FJuly
# Result: FJuly
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 0]
# lst: Aypril
# lst: vAypril
# Result: vAypril
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [5, 1]
# lst: Januaxry
# lst: JJanuaxry
# Result: JJanuaxry
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [1, 0]
# lst: Avugust
# lst: UAvugust
# Result: UAvugust
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [4, 5]
# lst: FebrHuary
# lst: FebrHsuary
# Result: FebrHsuary
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [5, 2]
# lst: Januaxry
# lst: Jaznuaxry
# Result: Jaznuaxry
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: Juqne
# Result: Juqne
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [1]
# lst: MRay
# Result: MRay
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [4, 6]
# lst: OctoUber
# lst: OctoUbaer
# Result: OctoUbaer
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 1]
# lst: uNovember
# lst: uyNovember
# Result: uyNovember
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 2]
# lst: DecembNer
# lst: DePcembNer
# Result: DePcembNer
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 2]
# lst: gDecember
# lst: gDOecember
# Result: gDOecember
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [1, 2]
# lst: Azugust
# lst: AzUugust
# Result: AzUugust
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [1, 2]
# lst: Oxctober
# lst: Oxictober
# Result: Oxictober
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [0, 4]
# lst: jMarch
# lst: jMarxch
# Result: jMarxch
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [3, 6]
# lst: OctTober
# lst: OctTobEer
# Result: OctTobEer
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [0, 3]
# lst: FJanuary
# lst: FJawnuary
# Result: FJawnuary
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [4, 2]
# lst: MarcVh
# lst: MaKrcVh
# Result: MaKrcVh
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: Jkune
# Result: Jkune
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: JunGe
# Result: JunGe
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 2]
# lst: MTarch
# lst: MTlarch
# Result: MTlarch
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 4]
# lst: Daecember
# lst: Daecyember
# Result: Daecyember
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 7]
# lst: Fmebruary
# lst: FmebruaNry
# Result: FmebruaNry
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: JZuly
# Result: JZuly
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [4, 1]
# lst: MarcMh
# lst: MrarcMh
# Result: MrarcMh
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [1]
# lst: JAuly
# Result: JAuly
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [5, 3]
# lst: OctobZer
# lst: OctSobZer
# Result: OctSobZer
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 4]
# lst: ANpril
# lst: ANprXil
# Result: ANprXil
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [0, 3]
# lst: YApril
# lst: YApGril
# Result: YApGril
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [4, 5]
# lst: DeceBmber
# lst: DeceBEmber
# Result: DeceBEmber
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: JuFly
# Result: JuFly
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 7]
# lst: FebruaZry
# lst: FebruaZKry
# Result: FebruaZKry
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [2, 4]
# lst: Ocwtober
# lst: Ocwtiober
# Result: Ocwtiober
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [3, 0]
# lst: Octnober
# lst: MOctnober
# Result: MOctnober
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [2]
# lst: Jucly
# Result: Jucly
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [0, 5]
# lst: mNovember
# lst: mNoveUmber
# Result: mNoveUmber
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [7, 6]
# lst: FebruarHy
# lst: FebruaqrHy
# Result: FebruaqrHy
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [3, 5]
# lst: NovNember
# lst: NovNeFmber
# Result: NovNeFmber
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [3, 2]
# lst: Marfch
# lst: MaCrfch
# Result: MaCrfch
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 2]
# lst: MCarch
# lst: MCFarch
# Result: MCFarch
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [0, 6]
# lst: ZOctober
# lst: ZOctobjer
# Result: ZOctobjer
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [1, 0]
# lst: MBarch
# lst: rMBarch
# Result: rMBarch
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [1, 4]
# lst: NSovember
# lst: NSovVember
# Result: NSovVember
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [3, 2]
# lst: AprPil
# lst: ApDrPil
# Result: ApDrPil
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: Julzy
# Result: Julzy
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [4, 5, 8]
# lst: SeptOember
# lst: SeptObember
# lst: SeptObemDber
# Result: SeptObemDber
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: cJuly
# Result: cJuly
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [3, 4]
# lst: Augtust
# lst: AugtDust
# Result: AugtDust
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [8, 5, 1]
# lst: Septembesr
# lst: SepteUmbesr
# lst: SgepteUmbesr
# Result: SgepteUmbesr
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 1
# selected positions: [0]
# lst: jMay
# Result: jMay
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [0, 1, 4]
# lst: iSeptember
# lst: iESeptember
# lst: iESenptember
# Result: iESenptember
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [2, 4]
# lst: AuOgust
# lst: AuOgRust
# Result: AuOgRust
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [3]
# lst: Junde
# Result: Junde
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: rJuly
# Result: rJuly
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [6, 1]
# lst: JanuarGy
# lst: JDanuarGy
# Result: JDanuarGy
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 1
# selected positions: [0]
# lst: RJune
# Result: RJune
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [6, 3]
# lst: Februairy
# lst: Febvruairy
# Result: Febvruairy
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 2
# selected positions: [4, 2]
# lst: Febriuary
# lst: Fefbriuary
# Result: Fefbriuary
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 3
# selected positions: [4, 5, 3]
# lst: SeptCember
# lst: SeptCOember
# lst: SepEtCOember
# Result: SepEtCOember
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 2
# selected positions: [1, 0]
# lst: AEugust
# lst: jAEugust
# Result: jAEugust
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 2
# selected positions: [3, 6]
# lst: JanJuary
# lst: JanJuakry
# Result: JanJuakry
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 4
# selected positions: [1, 2, 8, 4]
# lst: Sjeptember
# lst: Sjeeptember
# lst: Sjeeptemqber
# lst: Sjeeoptemqber
# Result: Sjeeoptemqber
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 3
# selected positions: [3, 1, 4]
# lst: Janduary
# lst: Jqanduary
# lst: JqanCduary
# Result: JqanCduary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [4, 0]
# lst: ApriLl
# lst: gApriLl
# Result: gApriLl
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [0, 1]
# lst: iMarch
# lst: iMMarch
# Result: iMMarch
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 4
# selected positions: [6, 7, 4, 8]
# lst: SeptemPber
# lst: SeptemPLber
# lst: SeptuemPLber
# lst: SeptuemPpLber
# Result: SeptuemPpLber
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 2
# selected positions: [4, 1]
# lst: ApriXl
# lst: AvpriXl
# Result: AvpriXl
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 3
# selected positions: [1, 3, 6]
# lst: DGecember
# lst: DGeycember
# lst: DGeyceimber
# Result: DGeyceimber
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 3
# selected positions: [3, 6, 0]
# lst: NovKember
# lst: NovKemWber
# lst: kNovKemWber
# Result: kNovKemWber
#
#
# row: 8
# ...
# lst: Aprvil
# lst: QAprvil
# lst: QhAprvil
# lst: QhxAprvil
# lst: QhxAzprvil
# Result: QhxAzprvil
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [1, 0, 4, 2, 3]
# lst: Mparch
# lst: cMparch
# lst: cMpaErch
# lst: cMfpaErch
# lst: cMfwpaErch
# Result: cMfwpaErch
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [4, 1, 6, 0, 3, 5, 7, 2]
# lst: NoveFmber
# lst: NFoveFmber
# lst: NFoveFHmber
# lst: INFoveFHmber
# lst: INFAoveFHmber
# lst: INFAotveFHmber
# lst: INFAotvReFHmber
# lst: INzFAotvReFHmber
# Result: INzFAotvReFHmber
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 6
# selected positions: [3, 1, 2, 4, 5, 0]
# lst: AugUust
# lst: AOugUust
# lst: AOaugUust
# lst: AOauZgUust
# lst: AOauZjgUust
# lst: oAOauZjgUust
# Result: oAOauZjgUust
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 9
# selected positions: [4, 1, 0, 5, 2, 6, 3, 8, 7]
# lst: SeptAember
# lst: SJeptAember
# lst: OSJeptAember
# lst: OSJepXtAember
# lst: OSCJepXtAember
# lst: OSCJepaXtAember
# lst: OSCRJepaXtAember
# lst: OSCRJepanXtAember
# lst: OSCRJepeanXtAember
# Result: OSCRJepeanXtAember
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 3
# selected positions: [2, 1, 0]
# lst: MaXy
# lst: MpaXy
# lst: BMpaXy
# Result: BMpaXy
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 3
# selected positions: [1, 0, 2]
# lst: Mlay
# lst: DMlay
# lst: DMClay
# Result: DMClay
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [0, 2, 1, 3, 6, 4, 5, 7]
# lst: IFebruary
# lst: IFxebruary
# lst: InFxebruary
# lst: InFrxebruary
# lst: InFrxehbruary
# lst: InFrPxehbruary
# lst: InFrPWxehbruary
# lst: InFrPWxuehbruary
# Result: InFrPWxuehbruary
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 3, 2, 0]
# lst: JRuly
# lst: JRuhly
# lst: JRjuhly
# lst: yJRjuhly
# Result: yJRjuhly
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [3, 2, 0, 1, 4]
# lst: AprEil
# lst: AprrEil
# lst: wAprrEil
# lst: wwAprrEil
# lst: wwApGrrEil
# Result: wwApGrrEil
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [2, 3, 6, 1, 0, 5, 4]
# lst: Jannuary
# lst: JanInuary
# lst: JanInucary
# lst: JTanInucary
# lst: VJTanInucary
# lst: VJTanOInucary
# lst: VJTaJnOInucary
# Result: VJTaJnOInucary
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 6
# selected positions: [2, 1, 0, 4, 5, 3]
# lst: Aujgust
# lst: AVujgust
# lst: UAVujgust
# lst: UAVudjgust
# lst: UAVudKjgust
# lst: UAVbudKjgust
# Result: UAVbudKjgust
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [6, 3, 4, 2, 0, 7, 5, 1]
# lst: Februaury
# lst: Febaruaury
# lst: FebaYruaury
# lst: FeybaYruaury
# lst: HFeybaYruaury
# lst: HFeybaYZruaury
# lst: HFeybgaYZruaury
# lst: HnFeybgaYZruaury
# Result: HnFeybgaYZruaury
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [0, 6, 5, 1, 3, 2, 4]
# lst: ZJanuary
# lst: ZJanuaxry
# lst: ZJanuQaxry
# lst: ZnJanuQaxry
# lst: ZnJGanuQaxry
# lst: ZnsJGanuQaxry
# lst: ZnsJCGanuQaxry
# Result: ZnsJCGanuQaxry
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [2, 3, 0, 1]
# lst: JuNne
# lst: JuNLne
# lst: NJuNLne
# lst: NOJuNLne
# Result: NOJuNLne
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 3
# selected positions: [2, 1, 0]
# lst: MaDy
# lst: MgaDy
# lst: bMgaDy
# Result: bMgaDy
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [5, 2, 0, 3, 4, 1, 6]
# lst: OctobJer
# lst: OcLtobJer
# lst: kOcLtobJer
# lst: kOcOLtobJer
# lst: kOcONLtobJer
# lst: kqOcONLtobJer
# lst: kqOcONBLtobJer
# Result: kqOcONBLtobJer
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [4, 6, 7, 3, 1, 5, 2, 0]
# lst: Novexmber
# lst: NovexmJber
# lst: NovexmJHber
# lst: NovQexmJHber
# lst: NdovQexmJHber
# lst: NdovQkexmJHber
# lst: NduovQkexmJHber
# lst: NNduovQkexmJHber
# Result: NNduovQkexmJHber
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [1, 7, 0, 6, 3, 2, 5, 4]
# lst: DIecember
# lst: DIecembher
# lst: HDIecembher
# lst: HDIecehmbher
# lst: HDIIecehmbher
# lst: HDaIIecehmbher
# lst: HDaIIuecehmbher
# lst: HDaIgIuecehmbher
# Result: HDaIgIuecehmbher
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [3, 7, 5, 6, 4, 2, 0, 1]
# lst: DecTember
# lst: DecTembFer
# lst: DecTeGmbFer
# lst: DecTeGPmbFer
# lst: DecTTeGPmbFer
# lst: DeOcTTeGPmbFer
# lst: yDeOcTTeGPmbFer
# lst: yRDeOcTTeGPmbFer
# Result: yRDeOcTTeGPmbFer
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 6
# selected positions: [3, 5, 4, 0, 1, 2]
# lst: Augdust
# lst: AugduNst
# lst: AugdLuNst
# lst: JAugdLuNst
# lst: JtAugdLuNst
# lst: JtUAugdLuNst
# Result: JtUAugdLuNst
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [0, 1, 5, 3, 4, 2, 6]
# lst: HOctober
# lst: HNOctober
# lst: HNOctZober
# lst: HNOZctZober
# lst: HNOZGctZober
# lst: HNGOZGctZober
# lst: HNGOZGBctZober
# Result: HNGOZGBctZober
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [1, 4, 3, 0, 2]
# lst: MDarch
# lst: MDarvch
# lst: MDajrvch
# lst: MMDajrvch
# lst: MMwDajrvch
# Result: MMwDajrvch
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [6, 4, 3, 0, 5, 2, 1]
# lst: Octobelr
# lst: Octovbelr
# lst: Octpovbelr
# lst: OOctpovbelr
# lst: OOctpwovbelr
# lst: OOCctpwovbelr
# lst: OcOCctpwovbelr
# Result: OcOCctpwovbelr
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [3, 4, 0, 5, 1, 6, 2]
# lst: Janauary
# lst: Janawuary
# lst: FJanawuary
# lst: FJanaAwuary
# lst: FyJanaAwuary
# lst: FyJanaFAwuary
# lst: FypJanaFAwuary
# Result: FypJanaFAwuary
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [3, 1, 2, 0, 4]
# lst: Marbch
# lst: MKarbch
# lst: MKQarbch
# lst: aMKQarbch
# lst: aMKQKarbch
# Result: aMKQKarbch
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [0, 1, 3, 2]
# lst: tJune
# lst: tMJune
# lst: tMJxune
# lst: tMVJxune
# Result: tMVJxune
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [0, 2, 3, 1]
# lst: YJune
# lst: YJXune
# lst: YJXWune
# lst: YfJXWune
# Result: YfJXWune
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [0, 1, 2, 3, 4]
# lst: MMarch
# lst: MHMarch
# lst: MHfMarch
# lst: MHfwMarch
# lst: MHfwNMarch
# Result: MHfwNMarch
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [5, 4, 1, 2, 0, 6, 3, 7]
# lst: Decemnber
# lst: DeceWmnber
# lst: DjeceWmnber
# lst: DjeeceWmnber
# lst: qDjeeceWmnber
# lst: qDjeecxeWmnber
# lst: qDjoeecxeWmnber
# lst: qDjoeectxeWmnber
# Result: qDjoeectxeWmnber
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [6, 4, 2, 3, 7, 5, 1, 0]
# lst: Februalry
# lst: FebrNualry
# lst: FeTbrNualry
# lst: FeTWbrNualry
# lst: FeTWbrNxualry
# lst: FeTWbMrNxualry
# lst: FheTWbMrNxualry
# lst: kFheTWbMrNxualry
# Result: kFheTWbMrNxualry
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 3, 2, 0]
# lst: Jouly
# lst: JouDly
# lst: JoPuDly
# lst: JJoPuDly
# Result: JJoPuDly
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [0, 1, 2, 4, 3]
# lst: HMarch
# lst: HWMarch
# lst: HWZMarch
# lst: HWZMdarch
# lst: HWZSMdarch
# Result: HWZSMdarch
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 2, 3, 0]
# lst: JFuly
# lst: JFruly
# lst: JFrwuly
# lst: TJFrwuly
# Result: TJFrwuly
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [2, 3, 1, 5, 6, 0, 4]
# lst: OcMtober
# lst: OcMptober
# lst: OycMptober
# lst: OycMputober
# lst: OycMpubtober
# lst: rOycMpubtober
# lst: rOycFMpubtober
# Result: rOycFMpubtober
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [1, 4, 0, 2, 3]
# lst: AZpril
# lst: AZprsil
# lst: eAZprsil
# lst: eARZprsil
# lst: eARRZprsil
# Result: eARRZprsil
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [4, 0, 1, 2, 3]
# lst: Aprill
# lst: cAprill
# lst: cYAprill
# lst: cYeAprill
# lst: cYeBAprill
# Result: cYeBAprill
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [5, 7, 1, 3, 4, 6, 2, 0]
# lst: Decemdber
# lst: DecemdbAer
# lst: DXecemdbAer
# lst: DXefcemdbAer
# lst: DXefQcemdbAer
# lst: DXefQccemdbAer
# lst: DXfefQccemdbAer
# lst: KDXfefQccemdbAer
# Result: KDXfefQccemdbAer
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 3, 2, 0]
# lst: Jbuly
# lst: Jbuwly
# lst: Jbpuwly
# lst: aJbpuwly
# Result: aJbpuwly
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [0, 4, 1, 5, 6, 2, 7, 3]
# lst: WFebruary
# lst: WFebfruary
# lst: WHFebfruary
# lst: WHFebMfruary
# lst: WHFebMbfruary
# lst: WHgFebMbfruary
# lst: WHgFebMlbfruary
# lst: WHgXFebMlbfruary
# Result: WHgXFebMlbfruary
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [4, 0, 5, 1, 6, 3, 2]
# lst: Octokber
# lst: fOctokber
# lst: fOctoykber
# lst: fuOctoykber
# lst: fuOctoKykber
# lst: fuOFctoKykber
# lst: fuYOFctoKykber
# Result: fuYOFctoKykber
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [0, 3, 2, 5, 1, 6, 4]
# lst: kOctober
# lst: kOcXtober
# lst: kOWcXtober
# lst: kOWcXmtober
# lst: kZOWcXmtober
# lst: kZOWcXgmtober
# lst: kZOWmcXgmtober
# Result: kZOWmcXgmtober
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 3, 0, 2]
# lst: JCuly
# lst: JCugly
# lst: DJCugly
# lst: DJVCugly
# Result: DJVCugly
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [1, 3, 6, 5, 0, 7, 4, 2]
# lst: Nmovember
# lst: NmoSvember
# lst: NmoSveAmber
# lst: NmoSvFeAmber
# lst: YNmoSvFeAmber
# lst: YNmoSvFTeAmber
# lst: YNmoaSvFTeAmber
# lst: YNLmoaSvFTeAmber
# Result: YNLmoaSvFTeAmber
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [1, 5, 0, 7, 6, 2, 4, 3]
# lst: Faebruary
# lst: FaebrCuary
# lst: xFaebrCuary
# lst: xFaebrCZuary
# lst: xFaebrnCZuary
# lst: xFtaebrnCZuary
# lst: xFtaqebrnCZuary
# lst: xFtXaqebrnCZuary
# Result: xFtXaqebrnCZuary
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [3, 4, 6, 5, 2, 7, 1, 0]
# lst: Novvember
# lst: NovvKember
# lst: NovvKenmber
# lst: NovvKienmber
# lst: NoTvvKienmber
# lst: NoTvvKibenmber
# lst: NZoTvvKibenmber
# lst: ONZoTvvKibenmber
# Result: ONZoTvvKibenmber
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [0, 3, 4, 1, 2]
# lst: MMarch
# lst: MMaLrch
# lst: MMaLkrch
# lst: MhMaLkrch
# lst: MhDMaLkrch
# Result: MhDMaLkrch
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [3, 1, 2, 4, 0]
# lst: Marcch
# lst: Mtarcch
# lst: MtKarcch
# lst: MtKazrcch
# lst: CMtKazrcch
# Result: CMtKazrcch
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [1, 3, 6, 2, 5, 4, 0]
# lst: Obctober
# lst: Obcatober
# lst: ObcatoZber
# lst: ObpcatoZber
# lst: ObpcaGtoZber
# lst: ObpctaGtoZber
# lst: KObpctaGtoZber
# Result: KObpctaGtoZber
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [3, 4, 1, 0, 2]
# lst: MarRch
# lst: MarRkch
# lst: MwarRkch
# lst: vMwarRkch
# lst: vMBwarRkch
# Result: vMBwarRkch
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [3, 5, 0, 6, 2, 7, 1, 4]
# lst: Novyember
# lst: NovyeGmber
# lst: HNovyeGmber
# lst: HNovyeiGmber
# lst: HNPovyeiGmber
# lst: HNPovyeViGmber
# lst: HyNPovyeViGmber
# lst: HyNPGovyeViGmber
# Result: HyNPGovyeViGmber
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to Add: 5
# selected positions: [4, 1, 2, 0, 3]
# lst: Aprikl
# lst: AZprikl
# lst: AZMprikl
# lst: JAZMprikl
# lst: JAZXMprikl
# Result: JAZXMprikl
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [0, 2, 1, 3]
# lst: GJuly
# lst: GJkuly
# lst: GjJkuly
# lst: GjJekuly
# Result: GjJekuly
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 9
# selected positions: [6, 1, 5, 8, 0, 2, 7, 4, 3]
# lst: SeptemZber
# lst: SjeptemZber
# lst: SjeptjemZber
# lst: SjeptjemMZber
# lst: fSjeptjemMZber
# lst: fSqjeptjemMZber
# lst: fSqjeptZjemMZber
# lst: fSqjqeptZjemMZber
# lst: fSqXjqeptZjemMZber
# Result: fSqXjqeptZjemMZber
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 0, 2, 3]
# lst: Jtuly
# lst: lJtuly
# lst: lJAtuly
# lst: lJAituly
# Result: lJAituly
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 6
# selected positions: [3, 0, 2, 4, 5, 1]
# lst: AugHust
# lst: wAugHust
# lst: wAVugHust
# lst: wAVuPgHust
# lst: wAVuPvgHust
# lst: wrAVuPvgHust
# Result: wrAVuPvgHust
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 9
# selected positions: [4, 7, 5, 2, 3, 1, 0, 8, 6]
# lst: SeptXember
# lst: SeptXemvber
# lst: SeptXQemvber
# lst: SeMptXQemvber
# lst: SeMxptXQemvber
# lst: SKeMxptXQemvber
# lst: LSKeMxptXQemvber
# lst: LSKeMxptnXQemvber
# lst: LSKeMxCptnXQemvber
# Result: LSKeMxCptnXQemvber
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to Add: 3
# selected positions: [0, 2, 1]
# lst: AMay
# lst: AMHay
# lst: ArMHay
# Result: ArMHay
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 9
# selected positions: [0, 7, 4, 3, 6, 1, 8, 5, 2]
# lst: sSeptember
# lst: sSeptemNber
# lst: sSepStemNber
# lst: sSekpStemNber
# lst: sSekpSYtemNber
# lst: sPSekpSYtemNber
# lst: sPSekpSYQtemNber
# lst: sPSekzpSYQtemNber
# lst: sPnSekzpSYQtemNber
# Result: sPnSekzpSYQtemNber
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 6
# selected positions: [5, 3, 2, 4, 1, 0]
# lst: AugusUt
# lst: AugIusUt
# lst: AuAgIusUt
# lst: AuAgsIusUt
# lst: AkuAgsIusUt
# lst: qAkuAgsIusUt
# Result: qAkuAgsIusUt
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 2, 0, 3]
# lst: Jwune
# lst: Jwbune
# lst: HJwbune
# lst: HJwMbune
# Result: HJwMbune
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 3, 2, 0]
# lst: JHuly
# lst: JHuuly
# lst: JHfuuly
# lst: RJHfuuly
# Result: RJHfuuly
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [0, 2, 4, 3, 5, 6, 1]
# lst: RJanuary
# lst: RJxanuary
# lst: RJxaYnuary
# lst: RJxkaYnuary
# lst: RJxkavYnuary
# lst: RJxkavxYnuary
# lst: RFJxkavxYnuary
# Result: RFJxkavxYnuary
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to Add: 4
# selected positions: [1, 2, 0, 3]
# lst: JYune
# lst: JYbune
# lst: TJYbune
# lst: TJYSbune
# Result: TJYSbune
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [3, 6, 2, 0, 1, 5, 7, 4]
# lst: FebSruary
# lst: FebSrudary
# lst: FeKbSrudary
# lst: LFeKbSrudary
# lst: LmFeKbSrudary
# lst: LmFeKVbSrudary
# lst: LmFeKVbwSrudary
# lst: LmFeGKVbwSrudary
# Result: LmFeGKVbwSrudary
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to Add: 8
# selected positions: [6, 1, 3, 7, 2, 5, 4, 0]
# lst: Februabry
# lst: Fsebruabry
# lst: Fsehbruabry
# lst: FsehbruMabry
# lst: FsNehbruMabry
# lst: FsNehnbruMabry
# lst: FsNeJhnbruMabry
# lst: zFsNeJhnbruMabry
# Result: zFsNeJhnbruMabry
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to Add: 9
# selected positions: [1, 0, 5, 3, 6, 4, 8, 7, 2]
# lst: Sieptember
# lst: OSieptember
# lst: OSiepBtember
# lst: OSitepBtember
# lst: OSitepABtember
# lst: OSitFepABtember
# lst: OSitFepAlBtember
# lst: OSitFepUAlBtember
# lst: OSsitFepUAlBtember
# Result: OSsitFepUAlBtember
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to Add: 6
# selected positions: [0, 3, 1, 2, 5, 4]
# lst: UAugust
# lst: UAuygust
# lst: UBAuygust
# lst: UBFAuygust
# lst: UBFAunygust
# lst: UBFAxunygust
# Result: UBFAxunygust
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to Add: 7
# selected positions: [5, 6, 2, 3, 1, 0, 4]
# lst: JanuaCry
# lst: JanuaCjry
# lst: JaknuaCjry
# lst: JakanuaCjry
# lst: JqakanuaCjry
# lst: vJqakanuaCjry
# lst: vJqaRkanuaCjry
# Result: vJqaRkanuaCjry

# %%
df
# Out:
#     Timestamp STD_Months   0.1_TypoC    0.2_TypoC     0.3_TypoC  \
# 0  2017-09-01  September  Septemeber  SeptemlYber  SeZptCDember
# 1  2017-06-01       June        June        Junue         Junie
# 2  2017-01-01    January    iJanuary     Januarby     eJanuarby
# 3  2017-09-01  September  Septeamber  Septfemhber  SepteRmbrber
# 4  2017-08-01     August     Axugust      IAugust      jASugust
# 5  2017-01-01    January    RJanuary     JDanuary     jJanuaLry
# 6  2017-06-01       June        June        JuJne         Juhne
# 7  2017-12-01   December   uDecember   DecemubOer    cDeScember
# 8  2017-11-01   November   NUovember   NoveimbeLr    Nagovember
# 9  2017-02-01   February   Fhebruary   FeebSruary    FCebrBuary
# 10 2017-01-01    January    ZJanuary     Januiary     bJRanuary
# 11 2017-04-01      April      Apsril       QApril       ApPrEil
# 12 2017-12-01   December   Decqember   DXeceZmber    Dxbecember
# 13 2017-02-01   February   FebIruary   Fevbhruary    XFFebruary
# 14 2017-12-01   December   Decemboer   DePmcember    TDecembeHr
# 15 2017-07-01       July        July        Jnuly         JuEly
# 16 2017-10-01    October    Octwober     OctSober     OhctAober
# 17 2017-04-01      April      Aperil       AprAil       zAvpril
# 18 2017-05-01        May         May         Mary          MaOy
# 19 2017-07-01       July        July        Jukly         JulKy
# 20 2017-12-01   December   Dxecember   Decoemuber    DecembAeur
# 21 2017-08-01     August     AugXust      XAugust      yAuguqst
# 22 2017-05-01        May         May         MUay          Mawy
# 23 2017-10-01    October    Occtober     OctobeAr     OictPober
# 24 2017-09-01  September  Septtember  SepGtembekr  SePpItembevr
# 25 2017-10-01    October    OUctober     OOctober     zOctobwer
# 26 2017-08-01     August     Augusst      XAugust      AuPggust
# 27 2017-12-01   December   Daecember   DecsembIer    aDecrember
# 28 2017-11-01   November   NovemEber   NHokvember    NIovvember
# 29 2017-12-01   December   HDecember   DFeFcember    Decemxbetr
# ..        ...        ...         ...          ...           ...
# 70 2017-03-01      March      Maarch       Mayrch       mMarOch
# 71 2017-07-01       July        July        Julvy         tJuly
# 72 2017-10-01    October    OctobeXr     xOctober     EOctcober
# 73 2017-01-01    January    Januaray     JanuAary     NJanbuary
# 74 2017-03-01      March      Marclh       MEarch       PMxarch
# 75 2017-03-01      March      Marcdh       Mqarch       MWarxch
# 76 2017-11-01   November   Novembker   NoCvejmber    uNovfember
# 77 2017-09-01  September  Sepdtember  SepteMmUber  sSeQptembger
# 78 2017-03-01      March      Mcarch       MaPrch       MarWcbh
# 79 2017-08-01     August     AuYgust      Augusvt      Augmucst
# 80 2017-02-01   February   eFebruary   FSebpruary    FueRbruary
# 81 2017-08-01     August     AuVgust      Auguset      LAuhgust
# 82 2017-07-01       July        July        Junly         JulXy
# 83 2017-09-01  September  SepteOmber  SeGptembear  SepmtPewmber
# 84 2017-02-01   February   FebruarWy   FFeJbruary    FSebruaIry
# 85 2017-01-01    January    GJanuary     Januakry     Janhuaory
# 86 2017-05-01        May         May         MFay          Mahy
# 87 2017-04-01      April      AprEil       Aspril       AxpCril
# 88 2017-06-01       June        June        qJune         JVune
# 89 2017-06-01       June        June        Juyne         Juqne
# 90 2017-12-01   December   DecWember   DePcemmber    nDecemboer
# 91 2017-05-01        May         May         Maiy          bMay
# 92 2017-03-01      March      MarcTh       Macrch       MKagrch
# 93 2017-02-01   February   eFebruary   FebrNuarry    WFebJruary
# 94 2017-07-01       July        July        JulMy         Jduly
# 95 2017-09-01  September  SeptBember  SeptjembNer  Sreptcexmber
# 96 2017-12-01   December   Decefmber   DlecTember    DecfeNmber
# 97 2017-06-01       June        June        Jwune         Jpune
# 98 2017-04-01      April      Aprikl       Arpril       TAFpril
# 99 2017-05-01        May         May         jMay          MaSy
#
#         0.4_TypoC       0.5_TypoC       0.6_TypoC        0.7_TypoC  \
# 0   SeTpErtemdber  SeiptejmJpUber  SaepQteNmLbNer  vSFeptkNOemWber
# 1          RJunse          Jbunje          KJuyne          JIxunLe
# 2      ToJanuafry     JYanLGzuary     JOanAfuJary     TJRaynEujary
# 3   SSaepStemXber  SejptwzegmSber  LSjQiepBtember  eSepjathembbemr
# 4        Axugukst       AbugNuXst      mAduHkgust       GlANuugust
# 5      JanxuAaTry     HJAVanupary     zJrzacnuary     LJanSQvuargy
# 6          xJfune          Jugnje          JuEnEe          JcuYune
# 7     DeZjcembker    DaecUeJmeber   ZDLeceoxImber   DTeRwTqcuember
# 8     NoRPvfember    TNovNxemlber   uENAovFxember   QNSoBKviecmber
# 9     FYeEbruWary    FkFebqcruary   FebRyruIVamry   tFYebomtrnuary
# 10     iqJaAnuary     SJacznuaJry     xJkpanuaLry     BJaCVlAnuary
# 11        jAApril        AWpyeril        eACpqril        xAQprgiAl
# 12    YDEecemUber    VDeceEgfmber   AGDeVcueSmber   cHDecRelmJdber
# 13    ZFebruuGary    OFGqebrXuary   FkLebJQrZuary   FXefVbruQfuary
# 14    DeiczemRber    DecZeiQmbher   ZLDeEcEZember   DHwebcUembWier
# 15         JPuyly          JuplMy          XJkuly          JKEauly
# 16     OOctkobXer     gORctaxober     OctrHoDbner     sjOJcutobzer
# 17        LAzpril        AtpkriKl        Aeptlril        KApWNDril
# 18           MaTy           kMxay           hvMay            Mlasy
# 19         JmXuly          UJulNy          YJudly          JGuukly
# 20    DCecBembTer    pDeMceEmkber   DekceWMkmbSer   DKqeHbcenmbIer
# 21       AEugwust       mAuguefst      uAygugjust       pAyRuygust
# 22           rMay           MWaly           MZaTy            ZMNay
# 23     AOctokbeNr     tOyctIoHber     EOtPcttober     jHObHctEober
# 24  SerptepmCDber  Sdepttemhbdefr  MSteYpteembetr  xSekpYtetmHTber
# 25     jOctLoberr     BsOhPctober     nOZctZHober     XOJXcgtobber
# 26       ApugusSt       AfuhguXst      vAgupgusDt       urjAugUust
# 27    DJecemmbeQr    lDecuembXfer   JmDelcHembJer   cgDewJceaXmber
# 28    NovemMBbecr    INwnovembeer   ZNosXmvembRer   eNobxveibmbeAr
# 29    DelcWevmber    uDecKemgbver   HDXepcCgember   zDuedSjcembTer
# ..            ...             ...             ...              ...
# 70        MMLarch        ypMGarch        Moarssch        WMYarBcoh
# 71         JGKuly          oJxuly          JwuHly          JUuqrly
# 72     OMctQobher     vOcStopbEer     gOctloxbesr     OsHctcUobZer
# 73     JanXunavry     eJaQInmuary     fJanfBuCary     iCJXanuzJary
# 74        MYDarch        MaMarcHh        sMwarrch        ESMaOrlch
# 75        oWMarch        KbMUarch        MMakRrch        hMzaUHrch
# 76    qNovemCkber    UNoLveGmbeFr   iNooHvembxcer   TNtogivPembler
# 77  SiiepoteWmber  tSepteYmkbTejr  SOBeptemCbdejr  kkSeAlfptTember
# 78        vMharch        cMELarch        HMuarXch        MgIamrcBh
# 79       AuMguNst       Atufgvust      jAlgugurst       pAdGugYust
# 80    FebirduarJy    PFeberJubary   tFSeburuCacry   NFQYSeSibruary
# 81       AtDugust       APguguast      AAtufguist       wAAHPugust
# 82         Jlumly          JuOEly          sJXuly          oJNGuly
# 83  vSheptWemgber  LSDRepteumbeSr  SeptEiebjmober  SePpGItWenqmber
# 84    FeSbrruawry    FeubNirsuary   FHeCrbnruanry   IFeNiibBVruary
# 85     EJNanukary     JainRuzayry     wJraanujary     JeaKnrbuxary
# 86           Mjay           MWaCy           MOaCy            MJpay
# 87        IAproil        WAapriZl        haApMril        FCAuprFil
# 88         Jtumne          JufnJe          XJunie          sJTMune
# 89         ejJune          JuMune          KJrune          JNTuYne
# 90    DecpemwbeRr    DlxeceQImber   DhefceRXmbmer   ODecrTEtcember
# 91           gMay           Mezay           MXbay            EMavy
# 92        CoMarch        MNaTrWch        AMamrych        MQllbarch
# 93    JFebmrQuary    FLfebrulEary   AFaebrszuaAry   EFuaezbRcruary
# 94         gJulRy          JSulWy          RJuxly          kJsulGy
# 95  GSeptKXexmber  OhSepctJembeWr  dSeQptemobeyer  SzSeibpQtembVer
# 96    DRecVembeHr    DsebceOmbEer   DSQeceLJTmber   lDeycHiembFeOr
# 97         JzuAne          iJRune          JWuene          FJcuJne
# 98        cAprVil        PnAMpril        aAZperil        AghJpGril
# 99           dMay           yMqay           MUaBy            FMayy
#
#            0.8_TypoC          0.9_TypoC             1_TypoC
# 0   SPRZzepHlDtember  vNSdeEPfCpEtember  rSdeepvnIRtwyember
# 1            JfJOune           BuJhuyne            wJFhuwne
# 2      HJYaSFnSuaFry      cSJianPuHanry      LukJaWXNntuary
# 3   ISoSeGpwteumbeor  GyTiSeKeQptembXer  qSsYepeMtzQHemJber
# 4        bAniugguust        GAtgDugAust        uIAjiulguSst
# 5      lJkaJnreuaAry      WJxaDnPulaNry      GJdaInGnuZUary
# 6            Jjniune           VtJASune            hJMyuqne
# 7     DoRReBcaFember    pEDIecCePmEbXer    GlDeIJUoXceUmber
# 8     LzNBsDovwember    aNNOoyveZxmbeWr    fXNozHzvqeumdber
# 9     dFebVIGvruEary    tFBGeJHbTrRuary    tFYQecAKbACruary
# 10     YJjOZanugarpy      DJMNaeAnUuary      dJOPxaCnuaPrxy
# 11         vYApOrCil         rijApEyril          hoApChrcil
# 12    DBegYctHmember    OquCDrecemkbQer    heuDeluceFmbCEer
# 13    xFERebNyrxuary    bFtHBbepbzruary    iUNFeleFbsbruary
# 14    XDPecrweTmbRer    IDRecmXTemwober    zDgvffLeqPcember
# 15           bWJulmy           OKBVJuly            GJlFbuly
# 16     pFPOctkvKober      FONScetobyeXr      KOscEIDRktober
# 17         bAGpyCril         oYAuprwiol          FoAWKprill
# 18             MSady             sMCIay              MMbauy
# 19           JrXuOly           QJFSpuly            UJadIuly
# 20    DpeETczemGWber    LXDlUzkecgember    BdDOecmKeNmIbZer
# 21       AaupFkfgust        JAVOuyguust        aaxAuEuRgust
# 22             XlMay             pyMJay              jWMavy
# 23     tOkyUcthAober      QOWrcFtboRber      POmefZcrtjober
# 24  SeCpPtiumdXember  wSiepqnSltIhember  DSGeFpaadjtXembeer
# 25     XnHROctoJWber      qdOcpXttobewr      PMkOctgoUZDber
# 26       ANudgsLZust        hAguOguxZst        uZAuWHcguxst
# 27    DTBecZCeCmbKer    WYDezjcSNembXer    xbDMJecaqeqPmber
# 28    lNosvmeEmmJber    eZINcOoVnvember    rJNYoqvpeOamvber
# 29    jDCepcenRqmber    DDBetcveRmpeber    oueDewqUcPembeSr
# ..               ...                ...                 ...
# 70         MSFarfcjh         NMKpaurcqh          NMnxkajrch
# 71           JTkukly           gJFDuAly            nYJuvBly
# 72     MOUJcdtEobker      kOucMntoTzber      QOkcShPtoRbemr
# 73     ljJaOnIuxaSry      tJrDDyyanuary      CJOVaWHsnuawry
# 74         vmMhgarch         cIuMairkch          kMCmarglch
# 75         EMbUaGrch         ZMMbahrdch          TkbMxQarch
# 76    NmJoQveOmbuger    hpNovCmbQEember    uNysMoPLveEmbemr
# 77  SdHepMStRXDember  zSNIxeQpatembqefr  NSOetqprtylZemWber
# 78         eWbMarnch         uMIQiaarch          PMMEOXarch
# 79       oAJugzQusPt        GAGhUvugust        FAVsBuJgBust
# 80    FTueibuIuruary    FleSfPKbruOEary    TFMelVbUrwmLuary
# 81       NAvugYDbust        SmfAugkSust        NAwFGugfuBst
# 82           bJuYlIy           hkhJulxy            stxfJuly
# 83  ISkueptsKwYember  BsgSeupHVRtemberr  arSHeFptjaatiember
# 84    FMRebuyrauaGry    FVjFezEmWbruary    LnFreZUebbruYary
# 85     XJfcaCnJeuary      FJagunIXIuary      bBAJIaWRnuatry
# 86             MVaTy             owMjay              fMxqay
# 87         aGgAprWil         NAVunpwril          reAkprrVil
# 88           cJZiune           ThJzurne            VJXscune
# 89           RJuRnVe           BOJmukne            bBJuwVne
# 90    DgIecaRemmbGer    IDDGegceeJtmber    cDiewrsceSymbKer
# 91             MRQay             ECMday              YzxMay
# 92         IwMaGrsch         OPcgfMarch          ICpMadWrch
# 93    dFejybArGuaVry    FleBZbrjBeuhary    FErFelbBSrbuanry
# 94           LcoJuly           xZJuxDly            TJBuJAly
# 95  aSuOcepEtembSOer  SaeufpytdeVmMvber  WBMSEWepttIemfzber
# 96    pDReMScCecmber    DrLecyeXokfmber    sHWDZxueZcembehr
# 97           JSurnde           uJAeunoe            GmJseune
# 98         VEApNrAil         GABbmprjil          bPApsRrvil
# 99             MALay             DMgaay              MMkpay
#
# [100 rows x 12 columns]

# %%
df.to_csv('C_NoisySet')
