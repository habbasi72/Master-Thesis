# %% [markdown]
# Class B is the typos of kind Cutting random letters
# First step :
# Creating a list of random timestamp
# Extracting only Month names

# %%
import pandas as pd
import numpy as np
import random
import string
from decimal import Decimal , ROUND_HALF_UP

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Import dataset
df=pd.read_csv('Initial.csv')
df=df.drop('Unnamed: 0' , 1)
df
# Out:
#     STD_Months
# 0    September
# 1      January
# 2        April
# 3        March
# 4    September
# 5        April
# 6     December
# 7     November
# 8      January
# 9        March
# 10      August
# 11     October
# 12       April
# 13        June
# 14    November
# 15        June
# 16         May
# 17    February
# 18        July
# 19      August
# 20       April
# 21    December
# 22         May
# 23       April
# 24         May
# 25    November
# 26        June
# 27     October
# 28   September
# 29      August
# ..         ...
# 90    February
# 91     October
# 92     October
# 93        July
# 94    November
# 95    February
# 96    November
# 97       March
# 98       March
# 99     October
# 100      March
# 101   November
# 102      April
# 103       July
# 104  September
# 105       July
# 106     August
# 107  September
# 108        May
# 109  September
# 110     August
# 111       June
# 112       July
# 113    January
# 114       June
# 115   February
# 116   February
# 117  September
# 118     August
# 119    January
#
# [120 rows x 1 columns]

# %%
Values = df['STD_Months'].value_counts()
print(Values)
Values.plot.barh()
plt.show()
# Out:
# October      10
# September    10
# June         10
# February     10
# August       10
# January      10
# December     10
# May          10
# November     10
# July         10
# April        10
# March        10
# Name: STD_Months, dtype: int64

# %%
#Creating 10% to 100% noise
p = [.1 , .2 , .3 , .4 , .5 , 0.6 , 0.7]

for pi in p:    
    #Extract the column's indices [0,1,...,99]
    df[str(pi)+'_TypoB'] = ''
    ix = [(row) for row in range(df['STD_Months'].shape[0])]
    
    for row in ix:
        print("row:" ,row)
        indxs = [i for i , _ in enumerate(df['STD_Months'].iat[row])]
        month = df['STD_Months'].iat[row]
        print(month)
        print ('Index:',indxs)
        length = len(indxs)
        print('length:' , length)
        
        #Coputing the no of letters to cut , considering the length of month
        letters = Decimal(str(length*pi)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
        print('letters to cut:' , letters)
        
        if letters>0:
            #Selecting random positions for cutting the letters
            positions = random.sample(range(length) , int(letters))
            print('selected positions:' , positions)
            
            for ind in positions:
                """ Replacing chosen letters with '-' """
                month = month[:ind] + "-" + month[ind+1:]
            #Cutting chosen letters                     
            month = month.replace("-" , "")    
            df[str(pi)+'_TypoB'].iat[row] = month
            print('Result:' , month)
            print('\n')
            
        else:
            print('No change!')
            df[str(pi)+'_TypoB'].iat[row] = df['STD_Months'].iat[row]
            print('\n')
# Out:
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [4]
# Result: Septmber
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [4]
# Result: Septmber
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [6]
# Result: Decembr
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [1]
# Result: Nvember
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [3]
# Result: Augst
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Octoer
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [2]
# Result: Noember
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [3]
# Result: Febuary
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ecember
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [1]
# Result: Nvember
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Octobe
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [0]
# Result: eptember
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [6]
# Result: Decembr
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [2]
# Result: Deember
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [2]
# Result: Deember
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ebruary
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Noveber
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [8]
# Result: Septembe
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [1]
# Result: Sptember
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [3]
# Result: Febuary
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [1]
# Result: Dcember
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Otober
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Marc
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [3]
# Result: Sepember
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [2]
# Result: Feruary
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [7]
# Result: Februar
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Otober
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Deceber
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [3]
# Result: Decmber
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: ctober
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Octber
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Janury
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: arch
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [6]
# Result: Decembr
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Febrary
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Otober
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Decemer
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [1]
# Result: Fbruary
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Otober
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Octber
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Novemer
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [3]
# Result: Febuary
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [2]
# Result: Noember
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Marh
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Marc
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Octoer
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Marc
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Novemer
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [5]
# Result: Septeber
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [7]
# Result: Septembr
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 0
# No change!
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [8]
# Result: Septembe
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [7]
# Result: Februar
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [3]
# Result: Febuary
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [8]
# Result: Septembe
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Janury
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [3, 7]
# Result: Sepembr
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [5, 3]
# Result: Sepeber
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 0]
# Result: ecembr
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 4]
# Result: Novebr
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Marh
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: ctober
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 1]
# Result: Nember
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 3]
# Result: Febary
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: uly
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 2]
# Result: Deeber
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 1]
# Result: vember
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: ctober
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 2]
# Result: Stember
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 7]
# Result: Novebe
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 6]
# Result: Decebr
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 2]
# Result: Deembe
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 7]
# Result: Deembe
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 7]
# Result: Februa
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 4]
# Result: Nveber
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 7]
# Result: Sptembr
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [6, 4]
# Result: Septmer
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 6]
# Result: Febuay
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 4]
# Result: Decebr
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: ctober
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Juy
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Marc
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 1]
# Result: Nveber
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [3, 1]
# Result: Spember
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 1]
# Result: Fbruay
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jly
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 3]
# Result: Febary
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Janury
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Octoer
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 4]
# Result: Novber
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 5]
# Result: ecemer
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 6]
# Result: Decemr
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Octber
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Mach
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Octobe
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Marh
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Marh
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 6]
# Result: Dcembr
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 4]
# Result: ebrary
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jul
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Mrch
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: uly
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Octber
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 3]
# Result: Decmbe
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jul
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 1]
# Result: Fbuary
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Octber
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Octoer
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jly
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 4]
# Result: Noveer
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 3]
# Result: Febuay
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 6]
# Result: Noembr
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: arch
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Marh
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Otober
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Marh
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 2]
# Result: Noembr
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jly
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [6, 1]
# Result: Sptemer
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Juy
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [3]
# Result: Augst
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [0, 2]
# Result: etember
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [3, 4]
# Result: Sepmber
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jul
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 3]
# Result: Febuay
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 2]
# Result: Feruay
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [2, 5]
# Result: Seteber
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [7, 2, 6]
# Result: Setemr
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [3, 1]
# Result: Jnary
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 3]
# Result: Arl
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 1]
# Result: Mch
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [1, 0, 4]
# Result: ptmber
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 3]
# Result: prl
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 4]
# Result: Deeber
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 4]
# Result: Novebe
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [4, 6]
# Result: Janur
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 3]
# Result: Mar
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 0]
# Result: ugut
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [2, 4]
# Result: Ocoer
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 4]
# Result: Api
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 0]
# Result: ovembe
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 7]
# Result: Febuar
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Juy
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [0, 5]
# Result: ugus
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 3]
# Result: Apl
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 5]
# Result: Dcemer
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 1]
# Result: Ari
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 1]
# Result: vember
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 1]
# Result: Otobe
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [8, 1, 7]
# Result: Sptemb
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 1]
# Result: Agut
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [5, 3]
# Result: Janay
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [0, 3]
# Result: anary
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 4]
# Result: Novebr
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 3]
# Result: ecmber
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 2]
# Result: Dember
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 4]
# Result: Decber
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [3, 6]
# Result: Janar
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 1]
# Result: Fbuary
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 5]
# Result: Novmer
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [5, 2, 7]
# Result: Setebr
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 0]
# Result: uust
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [0, 5, 8]
# Result: eptebe
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 7]
# Result: ebruar
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 4]
# Result: Dceber
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 5]
# Result: Octob
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: uly
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 0]
# Result: prl
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 4]
# Result: Mar
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 6]
# Result: Novemb
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [0, 3]
# Result: ugst
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [0, 4, 6]
# Result: eptmer
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 4]
# Result: Febrry
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: uly
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 4]
# Result: pri
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 5]
# Result: Janua
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 3]
# Result: Augt
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 5]
# Result: Febrry
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 2]
# Result: Jauar
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [3, 6]
# Result: Octbe
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 1]
# Result: Nember
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 6]
# Result: Deembr
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 3]
# Result: Decmbe
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 2]
# Result: Aust
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [0, 3]
# Result: ctber
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 3]
# Result: Mrh
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 0]
# Result: ctobe
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 3]
# Result: Janar
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 3]
# Result: Mrh
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 4]
# Result: Mrc
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 5]
# Result: Decemr
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 6]
# Result: Febray
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: uly
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 3]
# Result: Mah
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Juy
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [5, 3]
# Result: Octbr
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 4]
# Result: pri
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 4]
# Result: Apr
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 4]
# Result: Decebe
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jly
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 2]
# Result: Feruay
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 3]
# Result: Octbe
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [3, 0]
# Result: ctber
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jul
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 6]
# Result: Nvembr
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 2]
# Result: Ferury
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 1]
# Result: Nember
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 1]
# Result: rch
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 1]
# Result: rch
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [1, 5]
# Result: Otobr
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 0]
# Result: arh
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 3]
# Result: Novmbr
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 2]
# Result: Api
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Juy
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [0, 6, 2]
# Result: etemer
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: uly
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 2]
# Result: Auut
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [1, 5, 4]
# Result: Sptber
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [3, 0, 1]
# Result: pember
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [5, 1]
# Result: Agus
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Juy
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [0, 4]
# Result: anury
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 3]
# Result: Feuary
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 0]
# Result: ebuary
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [8, 0, 1]
# Result: ptembe
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 4]
# Result: Auut
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [3, 5]
# Result: Janay
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [8, 7, 1, 2]
# Result: Stemb
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [0, 2, 6]
# Result: auar
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 4]
# Result: Api
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 2]
# Result: ach
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [3, 8, 4, 7]
# Result: Sepmb
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 1]
# Result: Arl
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [4, 5, 2]
# Result: Deeer
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [5, 1, 0]
# Result: vemer
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [0, 5, 1]
# Result: nuay
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 1]
# Result: rch
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 5]
# Result: Auus
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [5, 4, 6]
# Result: Octo
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 2]
# Result: Api
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 3]
# Result: Jn
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [1, 2, 5]
# Result: Nemer
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 0]
# Result: ue
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 0, 6]
# Result: eruay
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [3, 0]
# Result: ul
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 3]
# Result: Augt
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 3]
# Result: prl
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [3, 7, 5]
# Result: Decme
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 2]
# Result: pil
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [0, 4, 6]
# Result: ovebr
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 1]
# Result: Je
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [0, 1, 6]
# Result: tobe
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [4, 1, 6, 2]
# Result: Stmer
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 0]
# Result: ugut
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [4, 3, 5]
# Result: Jany
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [2, 3, 4]
# Result: Jary
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 0, 4]
# Result: oeber
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [0, 4, 6]
# Result: ecebr
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [1, 6, 5]
# Result: Dcemr
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [4, 3, 6]
# Result: Decbr
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [5, 3, 4]
# Result: Jany
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [4, 1, 5]
# Result: Fbrry
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [0, 1, 5]
# Result: vemer
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [1, 0, 7, 3]
# Result: pembr
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 0]
# Result: ue
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 4]
# Result: Agut
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [8, 2, 1, 4]
# Result: Stmbe
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [7, 6, 0]
# Result: ebrua
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 3, 5]
# Result: Demer
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [1, 6, 5]
# Result: Otob
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [3, 2]
# Result: Ju
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 2]
# Result: Jy
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 3]
# Result: Apl
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 2]
# Result: ach
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [7, 3, 1]
# Result: Nvmbe
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 5]
# Result: Auus
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [2, 7, 5, 0]
# Result: etebr
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [1]
# Result: My
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [2]
# Result: Ma
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [4, 6, 5]
# Result: Febry
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [0, 2]
# Result: uy
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 2]
# Result: Ail
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [4, 1, 2]
# Result: Jury
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [5, 4]
# Result: Augu
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [3, 6, 7]
# Result: Febua
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [4, 2, 1]
# Result: Jury
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 3]
# Result: Jn
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 1
# selected positions: [0]
# Result: ay
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [6, 2, 4]
# Result: Ocoe
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [6, 3, 7]
# Result: Novmb
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [3, 5, 2]
# Result: Demer
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 5, 4]
# Result: Deeer
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 4]
# Result: Auut
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [1, 5, 6]
# Result: Otob
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 4]
# Result: Mar
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [6, 2, 4]
# Result: Ocoe
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [1, 2, 3]
# Result: Jary
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 2]
# Result: Mch
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 2]
# Result: Je
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [0, 3]
# Result: un
#
#
# ...
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [3, 2]
# Result: Ju
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [5, 0, 6, 1, 8]
# Result: ptee
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [0, 3]
# Result: ul
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 5, 3, 0]
# Result: us
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [8, 5, 4, 0, 3]
# Result: epbe
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [2, 0]
# Result: a
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [0, 5, 4, 6, 2]
# Result: eter
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 5, 2, 4]
# Result: Au
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 0]
# Result: ne
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 2]
# Result: Jy
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 4
# selected positions: [6, 0, 5, 4]
# Result: anu
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [0, 2]
# Result: ue
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 5
# selected positions: [5, 7, 6, 2, 3]
# Result: Feu
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 5
# selected positions: [0, 3, 7, 5, 4]
# Result: ebr
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [0, 1, 4, 3, 6]
# Result: pmer
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 0, 1, 5]
# Result: us
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 4
# selected positions: [3, 0, 2, 6]
# Result: aar
#
#
# row: 0
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [8, 0, 4, 3, 1, 5]
# Result: pbe
#
#
# row: 1
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 5, 6, 0, 4]
# Result: au
#
#
# row: 2
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 1, 4, 2]
# Result: A
#
#
# row: 3
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 2, 3, 1]
# Result: h
#
#
# row: 4
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [5, 0, 8, 2, 3, 6]
# Result: eee
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 3, 1, 4]
# Result: A
#
#
# row: 6
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 3, 0, 7, 1, 6]
# Result: cb
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [0, 6, 5, 7, 4, 1]
# Result: ve
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 0, 6, 1, 5]
# Result: ua
#
#
# row: 9
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 0, 3, 4]
# Result: r
#
#
# row: 10
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 5, 4, 1]
# Result: Au
#
#
# row: 11
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 6, 2, 4, 5]
# Result: Oo
#
#
# row: 12
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 3, 0, 4]
# Result: r
#
#
# row: 13
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 3]
# Result: u
#
#
# row: 14
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 3, 1, 2, 7, 6]
# Result: Nm
#
#
# row: 15
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 0, 2]
# Result: e
#
#
# row: 16
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [2, 1]
# Result: M
#
#
# row: 17
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 3, 1, 5, 0, 6]
# Result: by
#
#
# row: 18
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 1, 2]
# Result: J
#
#
# row: 19
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 5, 2, 0]
# Result: us
#
#
# row: 20
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [4, 2, 0, 1]
# Result: i
#
#
# row: 21
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 4, 0, 1, 3, 7]
# Result: ce
#
#
# row: 22
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [2, 1]
# Result: M
#
#
# row: 23
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 3, 4, 1]
# Result: r
#
#
# row: 24
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [1, 0]
# Result: y
#
#
# row: 25
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [3, 1, 7, 2, 6, 4]
# Result: Nb
#
#
# row: 26
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 3, 2]
# Result: J
#
#
# row: 27
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [6, 5, 3, 4, 1]
# Result: Ot
#
#
# row: 28
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [0, 4, 8, 2, 3, 6]
# Result: eme
#
#
# row: 29
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [1, 5, 4, 0]
# Result: gu
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 0, 1, 5, 6]
# Result: ua
#
#
# row: 31
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [4, 0, 5, 3, 1]
# Result: ny
#
#
# row: 32
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 7, 1, 5, 6, 0]
# Result: ve
#
#
# row: 33
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [6, 5, 3, 7, 4, 1]
# Result: Dc
#
#
# row: 34
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 4, 3, 0, 1, 7]
# Result: be
#
#
# row: 35
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 1, 3, 4, 7, 2]
# Result: De
#
#
# row: 36
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 4, 0, 5, 3]
# Result: ny
#
#
# row: 37
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 7, 5, 3, 4, 6]
# Result: Fb
#
#
# row: 38
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [1, 0]
# Result: y
#
#
# row: 39
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [0, 1]
# Result: y
#
#
# row: 40
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 0, 2, 5, 3, 6]
# Result: or
#
#
# row: 41
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [6, 8, 1, 7, 4, 0]
# Result: ptm
#
#
# row: 42
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 1]
# Result: e
#
#
# row: 43
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 1, 2, 0]
# Result: st
#
#
# row: 44
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [1, 5, 6, 8, 4, 0]
# Result: pte
#
#
# row: 45
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 4, 3, 2, 0, 7]
# Result: er
#
#
# row: 46
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [3, 4, 7, 5, 2, 1]
# Result: De
#
#
# row: 47
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 3, 4, 0, 5]
# Result: cr
#
#
# row: 48
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [1, 0]
# Result: y
#
#
# row: 49
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 1, 2]
# Result: e
#
#
# row: 50
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 2, 3]
# Result: J
#
#
# row: 51
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 3, 0, 4]
# Result: p
#
#
# row: 52
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 4, 2, 1]
# Result: c
#
#
# row: 53
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [6, 0, 4, 2, 5, 7]
# Result: oe
#
#
# row: 54
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 2, 0, 5]
# Result: us
#
#
# row: 55
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [5, 0, 6, 7, 2, 8]
# Result: ete
#
#
# row: 56
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [2, 1]
# Result: M
#
#
# row: 57
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [1, 0]
# Result: y
#
#
# row: 58
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [0, 3, 1, 5, 2, 6]
# Result: uy
#
#
# row: 59
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 2, 0]
# Result: y
#
#
# row: 60
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 4, 1, 0]
# Result: r
#
#
# row: 61
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [5, 3, 2, 6, 0]
# Result: aa
#
#
# row: 62
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [4, 3, 5, 2]
# Result: Au
#
#
# row: 63
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [0, 1, 2, 3, 4, 5]
# Result: ry
#
#
# row: 64
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [4, 6, 3, 5, 1]
# Result: Jn
#
#
# row: 65
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 1, 0]
# Result: n
#
#
# row: 66
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [2, 1]
# Result: M
#
#
# row: 67
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 3, 5, 1, 0]
# Result: br
#
#
# row: 68
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [0, 7, 5, 3, 6, 1]
# Result: vm
#
#
# row: 69
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 6, 5, 3, 0, 4]
# Result: er
#
#
# row: 70
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 2, 3, 4, 7, 0]
# Result: ee
#
#
# row: 71
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [0, 5, 2, 4]
# Result: uu
#
#
# row: 72
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 2, 6, 0, 3]
# Result: be
#
#
# row: 73
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 2, 1, 4]
# Result: c
#
#
# row: 74
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [0, 6, 4, 3, 1]
# Result: te
#
#
# row: 75
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 0, 5, 3, 4]
# Result: ay
#
#
# row: 76
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 4, 3, 2]
# Result: a
#
#
# row: 77
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 1]
# Result: e
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 0, 3]
# Result: n
#
#
# row: 79
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [4, 3, 0, 2]
# Result: a
#
#
# row: 80
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 7, 5, 3, 0, 6]
# Result: em
#
#
# row: 81
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 6, 0, 4, 7, 3]
# Result: ba
#
#
# row: 82
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 3, 0]
# Result: u
#
#
# row: 83
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 0, 1, 2]
# Result: h
#
#
# row: 84
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 3, 2]
# Result: u
#
#
# row: 85
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [3, 5, 2, 4, 6]
# Result: Oc
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 2, 4, 0]
# Result: p
#
#
# row: 87
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 0, 2, 3]
# Result: l
#
#
# row: 88
# December
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [6, 0, 1, 4, 7, 3]
# Result: cb
#
#
# row: 89
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 3, 1]
# Result: l
#
#
# row: 90
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 3, 6, 4, 7, 0]
# Result: ea
#
#
# row: 91
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [6, 3, 5, 0, 1]
# Result: tb
#
#
# row: 92
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [0, 2, 3, 4, 5]
# Result: cr
#
#
# row: 93
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 1, 0]
# Result: l
#
#
# row: 94
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [7, 2, 4, 1, 3, 6]
# Result: Nb
#
#
# row: 95
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 6, 3, 1, 2, 4]
# Result: Fy
#
#
# row: 96
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [6, 2, 7, 0, 5, 4]
# Result: oe
#
#
# row: 97
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [4, 3, 0, 1]
# Result: r
#
#
# row: 98
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 1, 3, 4]
# Result: r
#
#
# row: 99
# October
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [5, 6, 4, 3, 0]
# Result: ct
#
#
# row: 100
# March
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 0, 1, 3]
# Result: h
#
#
# row: 101
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [7, 6, 2, 4, 1, 3]
# Result: Nb
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 4, 2, 0]
# Result: p
#
#
# row: 103
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 2, 3]
# Result: J
#
#
# row: 104
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [2, 6, 7, 3, 1, 0]
# Result: emr
#
#
# row: 105
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 2, 0]
# Result: y
#
#
# row: 106
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [0, 3, 4, 1]
# Result: gt
#
#
# row: 107
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [5, 1, 4, 0, 6, 7]
# Result: ptr
#
#
# row: 108
# May
# Index: [0, 1, 2]
# length: 3
# letters to cut: 2
# selected positions: [1, 2]
# Result: M
#
#
# row: 109
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [7, 2, 0, 1, 4, 3]
# Result: mbr
#
#
# row: 110
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [4, 5, 1, 2]
# Result: Au
#
#
# row: 111
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 2, 0]
# Result: u
#
#
# row: 112
# July
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 3]
# Result: u
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [4, 3, 1, 6, 2]
# Result: Jr
#
#
# row: 114
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 1, 0]
# Result: e
#
#
# row: 115
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 2, 4, 7, 0, 1]
# Result: rr
#
#
# row: 116
# February
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 0, 6, 2, 4, 1]
# Result: ry
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [6, 8, 0, 5, 3, 2]
# Result: eee
#
#
# row: 118
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [0, 5, 4, 2]
# Result: uu
#
#
# row: 119
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 5, 6, 0, 2]
# Result: ua

# %%
df.to_csv('B_NoisySet')
