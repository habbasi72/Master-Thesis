# %%
import pandas as pd
import numpy as np
import random
from random import choice
import string
from decimal import Decimal , ROUND_HALF_UP
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('E_Initial.csv')
df=df.drop('Unnamed: 0' , 1)

# %%
Values = df['STD_Months'].value_counts()
print(Values)
Values.plot.barh()
plt.show()
# Out:
# April        20
# June         20
# November     20
# August       20
# January      20
# September    20
# Name: STD_Months, dtype: int64

# %%
#Percentages
p = [.1 , .2 , .3 , .4 , .5 , .6 , .7 , .8 , .9 , 1]

#Replacing letters with random ascii letters
def replace(*args):
    print("Typo: Replace")
    lst = list(month)
    result = ''
    for ind in positions:
        lst[ind]=random.choice(string.ascii_lowercase)
        result = ("".join(lst))
    print("result:",  result)
    return result

#Cutting letters from string
def cut(*args):
    print("Typo: Cut")
    Month=month
    for ind in positions:
        Month = Month[:ind] + "-" + Month[ind+1:]
    result = Month.replace("-" , "")  
    print("result:",  result)
    return result

#Adding random ascii letters to string
def add(*args):
    print("Typo: Add")
    Month = month
    for ind in positions:
        char = random.choice(string.ascii_letters)
        Month = Month[:ind] + char + Month[ind:]
    result = Month  
    print("result:",  result)
    return result  

for pi in p:
    print("Percentage==>" , pi)
    #Extract the column's indices [0,1,...,99]
    df[str(pi)+'_TypoD'] = ''
    
    #Iterate over the columns and rows
    ix = [(row) for row in range(df['STD_Months'].shape[0])]    
    for row in ix:
        print("row:" ,row)
        month = df['STD_Months'].iat[row]         
        print("MONTH:" , month)
        length = len(month)
        print("LENGTH:" , length)
        
        #Calculate number of letters to cut , considering the length of string
        letters = Decimal(str(length*pi)).quantize(Decimal("1") , rounding=ROUND_HALF_UP) 
                
        if letters > 0:
            positions = random.sample(range(length) , int(letters)) 
            print("POSITIONS:" , positions)
            #Choose randomly between 3 functions(Replace , Cut , Add)
            outcome = choice([replace , cut , add])(month , positions)
            df[str(pi)+'_TypoD'].iat[row] = outcome        
            print('\n')
            
        else:
            print('No Change!')
            df[str(pi)+'_TypoD'].iat[row] = month 
            print('\n')
            
    print('\n')
# Out:
# Percentage==> 0.1
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [0]
# Typo: Add
# result: ZJanuary
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Cut
# result: Augus
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Cut
# result: Janury
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [5]
# Typo: Add
# result: Novemkber
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: lpril
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Cut
# result: pril
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [4]
# Typo: Cut
# result: Noveber
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Add
# result: JaInuary
#
#
# row: 9
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Add
# result: AuguAst
#
#
# row: 10
# MONTH: November
# LENGTH: 8
# POSITIONS: [3]
# Typo: Replace
# result: Novkmber
#
#
# row: 11
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 12
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 13
# MONTH: September
# LENGTH: 9
# POSITIONS: [2]
# Typo: Replace
# result: Sestember
#
#
# row: 14
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Replace
# result: Auguet
#
#
# row: 15
# MONTH: April
# LENGTH: 5
# POSITIONS: [2]
# Typo: Cut
# result: Apil
#
#
# row: 16
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Cut
# result: Augus
#
#
# row: 17
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 18
# MONTH: November
# LENGTH: 8
# POSITIONS: [5]
# Typo: Cut
# result: Novemer
#
#
# row: 19
# MONTH: November
# LENGTH: 8
# POSITIONS: [4]
# Typo: Add
# result: Novedmber
#
#
# row: 20
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 21
# MONTH: November
# LENGTH: 8
# POSITIONS: [2]
# Typo: Cut
# result: Noember
#
#
# row: 22
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Add
# result: Janbuary
#
#
# row: 23
# MONTH: November
# LENGTH: 8
# POSITIONS: [3]
# Typo: Add
# result: NovMember
#
#
# row: 24
# MONTH: January
# LENGTH: 7
# POSITIONS: [0]
# Typo: Replace
# result: tanuary
#
#
# row: 25
# MONTH: September
# LENGTH: 9
# POSITIONS: [7]
# Typo: Cut
# result: Septembr
#
#
# row: 26
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: hpril
#
#
# row: 27
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Add
# result: gApril
#
#
# row: 28
# MONTH: April
# LENGTH: 5
# POSITIONS: [3]
# Typo: Replace
# result: Aprll
#
#
# row: 29
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Replace
# result: Janukry
#
#
# row: 30
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Cut
# result: Janary
#
#
# row: 31
# MONTH: November
# LENGTH: 8
# POSITIONS: [0]
# Typo: Cut
# result: ovember
#
#
# row: 32
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 33
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Cut
# result: Janury
#
#
# row: 34
# MONTH: September
# LENGTH: 9
# POSITIONS: [3]
# Typo: Replace
# result: Seprember
#
#
# row: 35
# MONTH: November
# LENGTH: 8
# POSITIONS: [3]
# Typo: Cut
# result: Novmber
#
#
# row: 36
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 37
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Cut
# result: pril
#
#
# row: 38
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Add
# result: Augunst
#
#
# row: 39
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Replace
# result: Januarb
#
#
# row: 40
# MONTH: September
# LENGTH: 9
# POSITIONS: [6]
# Typo: Add
# result: Septemgber
#
#
# row: 41
# MONTH: November
# LENGTH: 8
# POSITIONS: [2]
# Typo: Cut
# result: Noember
#
#
# row: 42
# MONTH: August
# LENGTH: 6
# POSITIONS: [2]
# Typo: Add
# result: AuZgust
#
#
# row: 43
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Replace
# result: Januarz
#
#
# row: 44
# MONTH: January
# LENGTH: 7
# POSITIONS: [5]
# Typo: Cut
# result: Januay
#
#
# row: 45
# MONTH: August
# LENGTH: 6
# POSITIONS: [3]
# Typo: Cut
# result: Augst
#
#
# row: 46
# MONTH: April
# LENGTH: 5
# POSITIONS: [3]
# Typo: Replace
# result: Aprel
#
#
# row: 47
# MONTH: November
# LENGTH: 8
# POSITIONS: [7]
# Typo: Cut
# result: Novembe
#
#
# row: 48
# MONTH: November
# LENGTH: 8
# POSITIONS: [7]
# Typo: Replace
# result: Novembei
#
#
# row: 49
# MONTH: November
# LENGTH: 8
# POSITIONS: [0]
# Typo: Replace
# result: rovember
#
#
# row: 50
# MONTH: November
# LENGTH: 8
# POSITIONS: [5]
# Typo: Cut
# result: Novemer
#
#
# row: 51
# MONTH: November
# LENGTH: 8
# POSITIONS: [0]
# Typo: Add
# result: ONovember
#
#
# row: 52
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 53
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 54
# MONTH: September
# LENGTH: 9
# POSITIONS: [8]
# Typo: Cut
# result: Septembe
#
#
# row: 55
# MONTH: November
# LENGTH: 8
# POSITIONS: [7]
# Typo: Replace
# result: Novembec
#
#
# row: 56
# MONTH: September
# LENGTH: 9
# POSITIONS: [7]
# Typo: Add
# result: SeptembKer
#
#
# row: 57
# MONTH: September
# LENGTH: 9
# POSITIONS: [8]
# Typo: Cut
# result: Septembe
#
#
# row: 58
# MONTH: September
# LENGTH: 9
# POSITIONS: [2]
# Typo: Add
# result: SeYptember
#
#
# row: 59
# MONTH: September
# LENGTH: 9
# POSITIONS: [4]
# Typo: Cut
# result: Septmber
#
#
# row: 60
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Add
# result: AugusWt
#
#
# row: 61
# MONTH: November
# LENGTH: 8
# POSITIONS: [4]
# Typo: Replace
# result: Novecber
#
#
# row: 62
# MONTH: September
# LENGTH: 9
# POSITIONS: [6]
# Typo: Replace
# result: Septemher
#
#
# row: 63
# MONTH: August
# LENGTH: 6
# POSITIONS: [0]
# Typo: Replace
# result: jugust
#
#
# row: 64
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [5]
# Typo: Cut
# result: Novemer
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Cut
# result: Janary
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [4]
# Typo: Cut
# result: Apri
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [4]
# Typo: Cut
# result: Apri
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: mpril
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [0]
# Typo: Cut
# result: eptember
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Cut
# result: pril
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Add
# result: AugusFt
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [6]
# Typo: Cut
# result: Septemer
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [2]
# Typo: Add
# result: Auggust
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [2]
# Typo: Add
# result: Sehptember
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [1]
# Typo: Replace
# result: Sxptember
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [2]
# Typo: Replace
# result: Auhust
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Replace
# result: Januarm
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Replace
# result: Augusl
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Cut
# result: Augut
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [4]
# Typo: Add
# result: ApriRl
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [3]
# Typo: Replace
# result: Aprnl
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [1]
# Typo: Cut
# result: Agust
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [1]
# Typo: Add
# result: Aqugust
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [0]
# Typo: Replace
# result: nugust
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [1]
# Typo: Cut
# result: Nvember
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [5]
# Typo: Cut
# result: Septeber
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [2]
# Typo: Cut
# result: Apil
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: Adpril
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [5]
# Typo: Cut
# result: Septeber
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Replace
# result: Januare
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [5]
# Typo: Cut
# result: Septeber
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [1]
# Typo: Replace
# result: Awgust
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Replace
# result: Januaro
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [2]
# Typo: Replace
# result: Apuil
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: Acpril
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [0]
# Typo: Add
# result: SJanuary
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: Anpril
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [1]
# Typo: Replace
# result: Nfvember
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: Agpril
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Cut
# result: Janury
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [3]
# Typo: Replace
# result: Augast
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [3]
# Typo: Cut
# result: Sepember
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Add
# result: JanuSary
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [1]
# Typo: Add
# result: Agugust
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Replace
# result: Jasuary
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [5]
# Typo: Cut
# result: Januay
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [2]
# Typo: Cut
# result: Setember
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# No Change!
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [0]
# Typo: Cut
# result: eptember
#
#
#
#
# Percentage==> 0.2
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [0]
# Typo: Cut
# result: anuary
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Replace
# result: Augusb
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [5]
# Typo: Cut
# result: Januay
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 1]
# Typo: Add
# result: NuovemDber
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: mpril
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Replace
# result: Aaril
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Cut
# result: une
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 0]
# Typo: Replace
# result: yovomber
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Add
# result: JaWnuary
#
#
# row: 9
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Replace
# result: Auguht
#
#
# row: 10
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 5]
# Typo: Replace
# result: aovemker
#
#
# row: 11
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Add
# result: Junxe
#
#
# row: 12
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Add
# result: JuVne
#
#
# row: 13
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 0]
# Typo: Cut
# result: eptemer
#
#
# row: 14
# MONTH: August
# LENGTH: 6
# POSITIONS: [0]
# Typo: Cut
# result: ugust
#
#
# row: 15
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Replace
# result: Adril
#
#
# row: 16
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Cut
# result: Augut
#
#
# row: 17
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Replace
# result: Junn
#
#
# row: 18
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 3]
# Typo: Replace
# result: Novtmser
#
#
# row: 19
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 1]
# Typo: Replace
# result: Njvezber
#
#
# row: 20
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Replace
# result: Jbne
#
#
# row: 21
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 2]
# Typo: Cut
# result: Noembr
#
#
# row: 22
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Add
# result: JanuarSy
#
#
# row: 23
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 0]
# Typo: Cut
# result: ovembe
#
#
# row: 24
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Replace
# result: Janaary
#
#
# row: 25
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 3]
# Typo: Add
# result: mSeFptember
#
#
# row: 26
# MONTH: April
# LENGTH: 5
# POSITIONS: [4]
# Typo: Replace
# result: Aprig
#
#
# row: 27
# MONTH: April
# LENGTH: 5
# POSITIONS: [3]
# Typo: Add
# result: Aprfil
#
#
# row: 28
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: ABpril
#
#
# row: 29
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Cut
# result: Janury
#
#
# row: 30
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Cut
# result: Jauary
#
#
# row: 31
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 7]
# Typo: Replace
# result: Nooembey
#
#
# row: 32
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Add
# result: JJune
#
#
# row: 33
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Cut
# result: Janury
#
#
# row: 34
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 8]
# Typo: Cut
# result: Septeme
#
#
# row: 35
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 3]
# Typo: Cut
# result: Nomber
#
#
# row: 36
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Cut
# result: Jue
#
#
# row: 37
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: zpril
#
#
# row: 38
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Add
# result: Augusgt
#
#
# row: 39
# MONTH: January
# LENGTH: 7
# POSITIONS: [1]
# Typo: Replace
# result: Jtnuary
#
#
# row: 40
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 3]
# Typo: Add
# result: SecTptember
#
#
# row: 41
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 2]
# Typo: Add
# result: NobveGmber
#
#
# row: 42
# MONTH: August
# LENGTH: 6
# POSITIONS: [2]
# Typo: Replace
# result: Auuust
#
#
# row: 43
# MONTH: January
# LENGTH: 7
# POSITIONS: [6]
# Typo: Replace
# result: Januaro
#
#
# row: 44
# MONTH: January
# LENGTH: 7
# POSITIONS: [4]
# Typo: Cut
# result: Janury
#
#
# row: 45
# MONTH: August
# LENGTH: 6
# POSITIONS: [2]
# Typo: Replace
# result: Audust
#
#
# row: 46
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Cut
# result: pril
#
#
# row: 47
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 6]
# Typo: Cut
# result: ovembr
#
#
# row: 48
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 6]
# Typo: Cut
# result: Noembr
#
#
# row: 49
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 0]
# Typo: Replace
# result: rcvember
#
#
# row: 50
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 4]
# Typo: Replace
# result: Novenbgr
#
#
# row: 51
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 2]
# Typo: Replace
# result: Nokemner
#
#
# row: 52
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Cut
# result: Jne
#
#
# row: 53
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Add
# result: JunSe
#
#
# row: 54
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 0]
# Typo: Cut
# result: eptemer
#
#
# row: 55
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 7]
# Typo: Replace
# result: Noxembek
#
#
# row: 56
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 5]
# Typo: Replace
# result: Septepbep
#
#
# row: 57
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 6]
# Typo: Cut
# result: Septemr
#
#
# row: 58
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 7]
# Typo: Replace
# result: Sepeembkr
#
#
# row: 59
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 3]
# Typo: Cut
# result: Sepemer
#
#
# row: 60
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Add
# result: Augucst
#
#
# row: 61
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 2]
# Typo: Replace
# result: Nogemker
#
#
# row: 62
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 8]
# Typo: Cut
# result: Sepembe
#
#
# row: 63
# MONTH: August
# LENGTH: 6
# POSITIONS: [0]
# Typo: Cut
# result: ugust
#
#
# row: 64
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Replace
# result: Jqne
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 4]
# Typo: Replace
# result: covewber
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Cut
# result: Jauary
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: zpril
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [3]
# Typo: Add
# result: Apriil
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Replace
# result: ipril
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 0]
# Typo: Add
# result: gSeptembMer
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Add
# result: zJune
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: Aypril
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Cut
# result: Augus
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 7]
# Typo: Add
# result: SeptembEeMr
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Replace
# result: Auguit
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 4]
# Typo: Add
# result: SeptheNmber
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 2]
# Typo: Cut
# result: Seteber
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Replace
# result: Jung
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [1]
# Typo: Add
# result: AHugust
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Replace
# result: Javuary
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Cut
# result: Jun
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [1]
# Typo: Replace
# result: Aagust
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Replace
# result: Junz
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [0]
# Typo: Replace
# result: zugust
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [3]
# Typo: Add
# result: Aprjil
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Add
# result: Aepril
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Cut
# result: une
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Add
# result: AuguSst
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Cut
# result: Jne
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [4]
# Typo: Cut
# result: Augut
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [3]
# Typo: Cut
# result: Augst
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 0]
# Typo: Add
# result: mNoveGmber
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 8]
# Typo: Cut
# result: eptembe
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [2]
# Typo: Replace
# result: Apcil
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [1]
# Typo: Replace
# result: Ahril
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 8]
# Typo: Replace
# result: Sepuembex
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Add
# result: Janouary
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Add
# result: JVune
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 8]
# Typo: Add
# result: hSeptembher
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [5]
# Typo: Cut
# result: Augus
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Add
# result: JaGnuary
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [4]
# Typo: Add
# result: ApriBl
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Cut
# result: pril
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Replace
# result: Jbne
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Cut
# result: Janary
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Cut
# result: pril
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 3]
# Typo: Cut
# result: Nvmber
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Add
# result: Juyne
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [0]
# Typo: Add
# result: hApril
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [1]
# Typo: Replace
# result: Jwnuary
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [3]
# Typo: Add
# result: AugYust
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 6]
# Typo: Cut
# result: Septeme
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [5]
# Typo: Replace
# result: Januavy
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [2]
# Typo: Add
# result: AuDgust
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [3]
# Typo: Cut
# result: Janary
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [2]
# Typo: Replace
# result: Jasuary
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 8]
# Typo: Add
# result: ESeptembser
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Cut
# result: une
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 1]
# Typo: Cut
# result: Sptembr
#
#
#
#
# Percentage==> 0.3
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 6]
# Typo: Add
# result: Januamtry
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 1]
# Typo: Add
# result: loAugust
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 6]
# Typo: Add
# result: JHanuaLry
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 7]
# Typo: Replace
# result: Novembmm
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 1]
# Typo: Replace
# result: Awrig
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3]
# Typo: Add
# result: ARpIril
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Replace
# result: dune
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 6]
# Typo: Add
# result: NcovemDber
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 1]
# Typo: Cut
# result: Jnury
#
#
# row: 9
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 1]
# Typo: Add
# result: AUugZust
#
#
# row: 10
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 0]
# Typo: Add
# result: HNovembenr
#
#
# row: 11
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Add
# result: Junle
#
#
# row: 12
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Add
# result: JuNne
#
#
# row: 13
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 8, 1]
# Typo: Cut
# result: Sptebe
#
#
# row: 14
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 0]
# Typo: Add
# result: JAugwust
#
#
# row: 15
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1]
# Typo: Cut
# result: Arl
#
#
# row: 16
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 0]
# Typo: Cut
# result: gust
#
#
# row: 17
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Cut
# result: Jue
#
#
# row: 18
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 3]
# Typo: Cut
# result: Novmbe
#
#
# row: 19
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 1]
# Typo: Replace
# result: Ngcember
#
#
# row: 20
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Replace
# result: Junc
#
#
# row: 21
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 6]
# Typo: Replace
# result: Nsvembqr
#
#
# row: 22
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 4]
# Typo: Cut
# result: Janur
#
#
# row: 23
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 3]
# Typo: Cut
# result: Novber
#
#
# row: 24
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 1]
# Typo: Cut
# result: Jnuar
#
#
# row: 25
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 0, 8]
# Typo: Add
# result: aSeoptemJber
#
#
# row: 26
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 2]
# Typo: Cut
# result: pil
#
#
# row: 27
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 4]
# Typo: Cut
# result: pri
#
#
# row: 28
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 2]
# Typo: Replace
# result: gptil
#
#
# row: 29
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 2]
# Typo: Cut
# result: Jaary
#
#
# row: 30
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 4]
# Typo: Add
# result: Janeduary
#
#
# row: 31
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 2]
# Typo: Add
# result: Nouvembedr
#
#
# row: 32
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Replace
# result: Jkne
#
#
# row: 33
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 2]
# Typo: Cut
# result: auary
#
#
# row: 34
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 1, 2]
# Typo: Cut
# result: tember
#
#
# row: 35
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 0]
# Typo: Cut
# result: ovmber
#
#
# row: 36
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Replace
# result: eune
#
#
# row: 37
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 1]
# Typo: Replace
# result: Aovil
#
#
# row: 38
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 2]
# Typo: Replace
# result: munust
#
#
# row: 39
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 6]
# Typo: Replace
# result: Januvrx
#
#
# row: 40
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 6, 0]
# Typo: Cut
# result: epteer
#
#
# row: 41
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 0]
# Typo: Cut
# result: ovemer
#
#
# row: 42
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 0]
# Typo: Add
# result: ZAsugust
#
#
# row: 43
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 3]
# Typo: Cut
# result: anary
#
#
# row: 44
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 2]
# Typo: Replace
# result: Jqeuary
#
#
# row: 45
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 3]
# Typo: Add
# result: mAungust
#
#
# row: 46
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 0]
# Typo: Add
# result: pAIpril
#
#
# row: 47
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 2]
# Typo: Cut
# result: Noembr
#
#
# row: 48
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 0]
# Typo: Cut
# result: oveber
#
#
# row: 49
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 6]
# Typo: Replace
# result: Noveabdr
#
#
# row: 50
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 0]
# Typo: Cut
# result: ovembe
#
#
# row: 51
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 2]
# Typo: Add
# result: NolvembIer
#
#
# row: 52
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Replace
# result: Jube
#
#
# row: 53
# MONTH: June
# LENGTH: 4
# POSITIONS: [0]
# Typo: Add
# result: JJune
#
#
# row: 54
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 7, 6]
# Typo: Replace
# result: Sepzemshr
#
#
# row: 55
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 2]
# Typo: Cut
# result: Nomber
#
#
# row: 56
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 0, 6]
# Typo: Replace
# result: heptemqgr
#
#
# row: 57
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 7, 1]
# Typo: Cut
# result: Sptmbr
#
#
# row: 58
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 2, 8]
# Typo: Replace
# result: Sectenbei
#
#
# row: 59
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 6, 7]
# Typo: Cut
# result: Sepemr
#
#
# row: 60
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 2]
# Typo: Replace
# result: Auiust
#
#
# row: 61
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 3]
# Typo: Add
# result: NovEemEber
#
#
# row: 62
# MONTH: September
# LENGTH: 9
# POSITIONS: [1, 7, 3]
# Typo: Cut
# result: Spembr
#
#
# row: 63
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 1]
# Typo: Cut
# result: Aust
#
#
# row: 64
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Add
# result: JBune
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 1]
# Typo: Replace
# result: Nfvembey
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 4]
# Typo: Replace
# result: Jynunry
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3]
# Typo: Add
# result: AGpkril
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 2]
# Typo: Replace
# result: Apfia
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 4]
# Typo: Replace
# result: Apqij
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 8, 0]
# Typo: Add
# result: TSeptKembFer
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Replace
# result: Jute
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 2]
# Typo: Replace
# result: Apwel
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 1]
# Typo: Replace
# result: Awguit
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 6, 2]
# Typo: Add
# result: SeFpteylmber
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 4]
# Typo: Add
# result: gAugcust
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 2, 4]
# Typo: Cut
# result: Setmer
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 7, 3]
# Typo: Replace
# result: Sepzemwhr
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Cut
# result: Jue
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 2]
# Typo: Replace
# result: hubust
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 4]
# Typo: Replace
# result: Janucrb
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Replace
# result: Jude
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 4]
# Typo: Add
# result: Atughust
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Add
# result: JuDne
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 1]
# Typo: Add
# result: AfuguMst
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 4]
# Typo: Replace
# result: Aerih
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 0]
# Typo: Cut
# result: prl
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Add
# result: Junle
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4]
# Typo: Replace
# result: Augplt
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Cut
# result: Jue
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 2]
# Typo: Replace
# result: Affust
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 4]
# Typo: Add
# result: OAugKust
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 3]
# Typo: Cut
# result: Novmbe
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 4, 2]
# Typo: Add
# result: SeAptleBmber
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3]
# Typo: Add
# result: AWpdril
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 1]
# Typo: Cut
# result: ril
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 5, 1]
# Typo: Replace
# result: Shatetber
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 1]
# Typo: Add
# result: JXanuarPy
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Cut
# result: Jun
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 0, 4]
# Typo: Add
# result: YSepGKtember
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4]
# Typo: Cut
# result: Augt
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 1]
# Typo: Replace
# result: Jwmuary
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 1]
# Typo: Cut
# result: Ail
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 4]
# Typo: Replace
# result: Ahril
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# POSITIONS: [1]
# Typo: Add
# result: Jbune
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 6]
# Typo: Add
# result: JxanuaXry
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 1]
# Typo: Cut
# result: ril
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 6]
# Typo: Cut
# result: ovembr
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# POSITIONS: [3]
# Typo: Replace
# result: Junx
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1]
# Typo: Cut
# result: Arl
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 5]
# Typo: Cut
# result: Jnuay
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 1]
# Typo: Add
# result: KJAugust
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 7, 5]
# Typo: Add
# result: SeptBmemrber
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 2]
# Typo: Cut
# result: Jauar
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4]
# Typo: Add
# result: AugWcust
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 6]
# Typo: Add
# result: NJanuaHry
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 1]
# Typo: Replace
# result: Jfnunry
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 1, 0]
# Typo: Cut
# result: pteber
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# POSITIONS: [2]
# Typo: Add
# result: JuFne
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 3, 2]
# Typo: Add
# result: SeSpPtembedr
#
#
#
#
# Percentage==> 0.4
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 5, 4]
# Typo: Add
# result: xJanbutary
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 3]
# Typo: Add
# result: Akurgust
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 0, 1]
# Typo: Add
# result: sYJanuSary
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 6, 0]
# Typo: Add
# result: BNovempXber
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 4]
# Typo: Replace
# result: Apiis
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 4]
# Typo: Add
# result: cApryil
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 3]
# Typo: Cut
# result: Ju
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 5, 1]
# Typo: Replace
# result: Nuvemter
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 1, 2]
# Typo: Add
# result: MlXJanuary
#
#
# row: 9
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 0]
# Typo: Cut
# result: ugst
#
#
# row: 10
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 2, 3]
# Typo: Cut
# result: Nober
#
#
# row: 11
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 1]
# Typo: Cut
# result: ne
#
#
# row: 12
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2]
# Typo: Cut
# result: Ju
#
#
# row: 13
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 2, 5, 8]
# Typo: Cut
# result: Seteb
#
#
# row: 14
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 1]
# Typo: Cut
# result: gust
#
#
# row: 15
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 2]
# Typo: Cut
# result: Apl
#
#
# row: 16
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 3]
# Typo: Replace
# result: Auggsx
#
#
# row: 17
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 2]
# Typo: Cut
# result: ue
#
#
# row: 18
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 6, 5]
# Typo: Replace
# result: Novemnaw
#
#
# row: 19
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 7, 1]
# Typo: Replace
# result: Nlvembit
#
#
# row: 20
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 3]
# Typo: Add
# result: Jurzne
#
#
# row: 21
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 2, 4]
# Typo: Add
# result: NoZvpemOber
#
#
# row: 22
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 5, 3]
# Typo: Replace
# result: Jajgapy
#
#
# row: 23
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 1, 0]
# Typo: Cut
# result: vembr
#
#
# row: 24
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 0, 6]
# Typo: Add
# result: MJanKuZary
#
#
# row: 25
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 6, 5, 8]
# Typo: Replace
# result: Septhgheo
#
#
# row: 26
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 1]
# Typo: Add
# result: AepDril
#
#
# row: 27
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 4]
# Typo: Cut
# result: Apr
#
#
# row: 28
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1]
# Typo: Cut
# result: Arl
#
#
# row: 29
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 6, 2]
# Typo: Cut
# result: Jaur
#
#
# row: 30
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 2, 4]
# Typo: Replace
# result: Jawgiry
#
#
# row: 31
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 0, 5]
# Typo: Cut
# result: oveer
#
#
# row: 32
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0]
# Typo: Replace
# result: buxe
#
#
# row: 33
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 5, 1]
# Typo: Cut
# result: Jnuy
#
#
# row: 34
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 6, 4, 3]
# Typo: Cut
# result: Sepme
#
#
# row: 35
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 6, 7]
# Typo: Cut
# result: ovemb
#
#
# row: 36
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2]
# Typo: Cut
# result: Ju
#
#
# row: 37
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 3]
# Typo: Cut
# result: Apl
#
#
# row: 38
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 0]
# Typo: Replace
# result: duuust
#
#
# row: 39
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 2, 0]
# Typo: Replace
# result: naducry
#
#
# row: 40
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 4, 3, 8]
# Typo: Cut
# result: Sembe
#
#
# row: 41
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 1, 4]
# Typo: Add
# result: GmNoMvember
#
#
# row: 42
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 2]
# Typo: Cut
# result: Aust
#
#
# row: 43
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 3, 2]
# Typo: Cut
# result: Jary
#
#
# row: 44
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 0, 5]
# Typo: Add
# result: IJanuvarBy
#
#
# row: 45
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 5]
# Typo: Add
# result: AugLunst
#
#
# row: 46
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 3]
# Typo: Add
# result: Aprsizl
#
#
# row: 47
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 6, 7]
# Typo: Add
# result: hNovemuVber
#
#
# row: 48
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 4, 0]
# Typo: Replace
# result: fcveiber
#
#
# row: 49
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 2, 5]
# Typo: Cut
# result: oemer
#
#
# row: 50
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 7, 4]
# Typo: Cut
# result: Novbe
#
#
# row: 51
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 7, 0]
# Typo: Cut
# result: oembe
#
#
# row: 52
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Replace
# result: Jbne
#
#
# row: 53
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 3]
# Typo: Cut
# result: Ju
#
#
# row: 54
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 1, 0, 4]
# Typo: Cut
# result: tmber
#
#
# row: 55
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 1, 0]
# Typo: Cut
# result: vembe
#
#
# row: 56
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 7, 1, 6]
# Typo: Cut
# result: ptemr
#
#
# row: 57
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 2, 0, 7]
# Typo: Add
# result: FSeKpteGqmber
#
#
# row: 58
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 2, 3, 6]
# Typo: Cut
# result: Seemr
#
#
# row: 59
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 2, 6, 8]
# Typo: Replace
# result: oeltemoek
#
#
# row: 60
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 5]
# Typo: Replace
# result: Augude
#
#
# row: 61
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 6, 4]
# Typo: Add
# result: NojvMemober
#
#
# row: 62
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 6, 3, 1]
# Typo: Replace
# result: Sqpiemvgr
#
#
# row: 63
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 1]
# Typo: Replace
# result: kggust
#
#
# row: 64
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0]
# Typo: Add
# result: bJunFe
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 1, 3]
# Typo: Cut
# result: vmber
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 1, 6]
# Typo: Replace
# result: ztnuarv
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 2]
# Typo: Add
# result: kALpril
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 0]
# Typo: Cut
# result: pil
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 1]
# Typo: Replace
# result: ypril
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 3, 6, 7]
# Typo: Replace
# result: Sepsecejr
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 2]
# Typo: Cut
# result: Je
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 4]
# Typo: Replace
# result: Apret
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 3]
# Typo: Add
# result: Augrupst
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 8, 6, 0]
# Typo: Add
# result: VSeptexNmbmer
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 4]
# Typo: Cut
# result: Augu
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [1, 4, 2, 3]
# Typo: Cut
# result: Smber
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 6, 1, 4]
# Typo: Cut
# result: Spmer
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0]
# Typo: Cut
# result: un
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 5]
# Typo: Replace
# result: Auwuss
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 3, 6]
# Typo: Add
# result: nJaYnuTary
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Cut
# result: Jn
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 3]
# Typo: Replace
# result: Augsjt
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 3]
# Typo: Cut
# result: Jn
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4]
# Typo: Cut
# result: Augt
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 2]
# Typo: Replace
# result: Aazil
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 0]
# Typo: Add
# result: HAperil
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0]
# Typo: Add
# result: GJujne
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4]
# Typo: Replace
# result: Aughzt
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0]
# Typo: Replace
# result: aunx
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 2]
# Typo: Add
# result: AuPgusjt
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 0]
# Typo: Add
# result: BAugKust
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 5, 7]
# Typo: Replace
# result: Novemnbo
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 1, 4, 3]
# Typo: Cut
# result: pmber
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 4]
# Typo: Cut
# result: Api
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 3]
# Typo: Add
# result: AprViFl
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 2, 4, 1]
# Typo: Add
# result: Sleeptitember
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 2, 5]
# Typo: Cut
# result: Jaay
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Add
# result: JcunQe
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 8, 4, 6]
# Typo: Add
# result: nSepptIembuer
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 2]
# Typo: Add
# result: AuEgusnt
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 6, 5]
# Typo: Cut
# result: Jnua
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1]
# Typo: Replace
# result: Ajrll
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 2]
# Typo: Replace
# result: Apval
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 3]
# Typo: Cut
# result: un
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 1, 3]
# Typo: Add
# result: JHacnumary
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 1]
# Typo: Add
# result: XBApril
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 4, 3]
# Typo: Cut
# result: Nober
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Cut
# result: Jn
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 2]
# Typo: Replace
# result: hpjil
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 6, 5]
# Typo: Replace
# result: Januhjb
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 5]
# Typo: Add
# result: AuguIyst
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 6, 5, 0]
# Typo: Add
# result: qSepteWmDbeur
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 4, 1]
# Typo: Add
# result: JGanusaGry
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 4]
# Typo: Add
# result: Augumsut
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 0, 3]
# Typo: Add
# result: iJaKnuaTry
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 0, 6]
# Typo: Add
# result: wJbanuqary
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 3, 7, 4]
# Typo: Add
# result: SepzutemBbevr
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2]
# Typo: Add
# result: JuYnte
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 6, 8, 4]
# Typo: Replace
# result: Septdifez
#
#
#
#
# Percentage==> 0.5
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 4, 2, 5]
# Typo: Replace
# result: nauuoiy
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 2, 4]
# Typo: Cut
# result: Aut
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 5, 1, 6]
# Typo: Add
# result: iNJanuEjary
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 1, 0, 4]
# Typo: Replace
# result: elrenber
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 1, 3]
# Typo: Add
# result: AtplriEl
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 1, 2]
# Typo: Replace
# result: Aocib
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 3]
# Typo: Add
# result: PJumne
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 0, 6, 1]
# Typo: Add
# result: ArNovemcbewr
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 5, 0, 6]
# Typo: Replace
# result: gynuadr
#
#
# row: 9
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 1, 5]
# Typo: Add
# result: AauSgsust
#
#
# row: 10
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 0, 2, 6]
# Typo: Cut
# result: oemr
#
#
# row: 11
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0]
# Typo: Replace
# result: yuke
#
#
# row: 12
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 2]
# Typo: Cut
# result: Je
#
#
# row: 13
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 5, 8, 4, 3]
# Typo: Replace
# result: Seponvbpw
#
#
# row: 14
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4, 2]
# Typo: Add
# result: AuEgLrust
#
#
# row: 15
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 1, 2]
# Typo: Replace
# result: wunil
#
#
# row: 16
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 5, 0]
# Typo: Cut
# result: ugu
#
#
# row: 17
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0]
# Typo: Add
# result: gJunve
#
#
# row: 18
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 4, 3, 6]
# Typo: Add
# result: NoLTvYUember
#
#
# row: 19
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 4, 2, 0]
# Typo: Cut
# result: oebe
#
#
# row: 20
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Add
# result: JnunSe
#
#
# row: 21
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 5, 4, 6]
# Typo: Cut
# result: over
#
#
# row: 22
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 3, 5, 4]
# Typo: Add
# result: JUagLnJuary
#
#
# row: 23
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 3, 4, 2]
# Typo: Replace
# result: Nollybjr
#
#
# row: 24
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 0, 4, 2]
# Typo: Replace
# result: aayhtry
#
#
# row: 25
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 4, 7, 5, 0]
# Typo: Add
# result: zSeptUSemkbelr
#
#
# row: 26
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 3, 1]
# Typo: Add
# result: APpFvril
#
#
# row: 27
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 1, 4]
# Typo: Replace
# result: wurit
#
#
# row: 28
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3, 4]
# Typo: Replace
# result: Aprpa
#
#
# row: 29
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 0, 1, 4]
# Typo: Cut
# result: nur
#
#
# row: 30
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 1, 4, 5]
# Typo: Add
# result: HrJapnnuary
#
#
# row: 31
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 5, 1, 4]
# Typo: Replace
# result: jpvebfer
#
#
# row: 32
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 3]
# Typo: Replace
# result: uunq
#
#
# row: 33
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 6, 0, 4]
# Typo: Cut
# result: nur
#
#
# row: 34
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 2, 8, 1, 7]
# Typo: Cut
# result: Stmb
#
#
# row: 35
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 3, 1, 7]
# Typo: Cut
# result: Nvbe
#
#
# row: 36
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 1]
# Typo: Cut
# result: ne
#
#
# row: 37
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 1, 3]
# Typo: Cut
# result: Ar
#
#
# row: 38
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 3, 2]
# Typo: Add
# result: AQButgust
#
#
# row: 39
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 0, 2, 4]
# Typo: Add
# result: JJoaOnuarYy
#
#
# row: 40
# MONTH: September
# LENGTH: 9
# POSITIONS: [1, 0, 7, 5, 2]
# Typo: Add
# result: XSJiepKtekmber
#
#
# row: 41
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 0, 5, 1]
# Typo: Add
# result: gTNowvMember
#
#
# row: 42
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 2, 5]
# Typo: Cut
# result: Aus
#
#
# row: 43
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 3, 5, 2]
# Typo: Add
# result: JaBnkuPzary
#
#
# row: 44
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 1, 5, 4]
# Typo: Replace
# result: Jwnawsy
#
#
# row: 45
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 2, 1]
# Typo: Cut
# result: ust
#
#
# row: 46
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 4, 1]
# Typo: Cut
# result: Ar
#
#
# row: 47
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 0, 4, 2]
# Typo: Replace
# result: doledbxr
#
#
# row: 48
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 5, 7, 3]
# Typo: Replace
# result: Novmezeb
#
#
# row: 49
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 7, 5, 2]
# Typo: Cut
# result: Noem
#
#
# row: 50
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 2, 0, 5]
# Typo: Add
# result: eNoKvNLember
#
#
# row: 51
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 0, 6, 4]
# Typo: Add
# result: KNovBqecmber
#
#
# row: 52
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 2]
# Typo: Add
# result: vJdune
#
#
# row: 53
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2]
# Typo: Cut
# result: Ju
#
#
# row: 54
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 7, 0, 6, 5]
# Typo: Replace
# result: deppeskwr
#
#
# row: 55
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 4, 2, 7]
# Typo: Replace
# result: Nodenbmr
#
#
# row: 56
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 8, 3, 2, 5]
# Typo: Add
# result: SeupdjtembzUer
#
#
# row: 57
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 6, 3, 8, 4]
# Typo: Cut
# result: Sepe
#
#
# row: 58
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 4, 5, 3, 8]
# Typo: Replace
# result: Seaiqabey
#
#
# row: 59
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 4, 1, 2, 7]
# Typo: Cut
# result: tmbr
#
#
# row: 60
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 3, 5]
# Typo: Cut
# result: Ags
#
#
# row: 61
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 4, 7, 6]
# Typo: Add
# result: NoveCmTeNber
#
#
# row: 62
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 7, 6, 5, 0]
# Typo: Add
# result: QSeptGSejmsber
#
#
# row: 63
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 3, 5]
# Typo: Replace
# result: Augftv
#
#
# row: 64
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2]
# Typo: Add
# result: JuanKe
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 5, 7, 4]
# Typo: Cut
# result: Noee
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 5, 4, 1]
# Typo: Add
# result: JfaUnhuDary
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 2, 4]
# Typo: Add
# result: ApqrOeil
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 4, 2]
# Typo: Cut
# result: Ai
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1, 0]
# Typo: Cut
# result: rl
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 0, 8, 7, 1]
# Typo: Replace
# result: rjptambkt
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Add
# result: JLunme
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1, 2]
# Typo: Replace
# result: Aukvl
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 2, 3]
# Typo: Add
# result: AxTMugust
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 3, 6, 2, 7]
# Typo: Cut
# result: Seem
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4, 0]
# Typo: Replace
# result: hugygt
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 2, 0, 6, 5]
# Typo: Cut
# result: etee
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 8, 4, 7, 6]
# Typo: Add
# result: jSepWtCepmbKer
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 2]
# Typo: Cut
# result: Je
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 5, 2]
# Typo: Cut
# result: Aus
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 1, 0, 2]
# Typo: Add
# result: qJmnanuairy
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 3]
# Typo: Cut
# result: Jn
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 4, 5]
# Typo: Cut
# result: Agu
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Replace
# result: Jqnx
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 5, 0]
# Typo: Add
# result: WAuGguhst
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 4, 2]
# Typo: Replace
# result: Aufil
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 0, 2]
# Typo: Cut
# result: pl
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0]
# Typo: Add
# result: dJutne
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 2, 3]
# Typo: Cut
# result: ust
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Cut
# result: Jn
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 1, 2]
# Typo: Cut
# result: Aut
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 1, 5]
# Typo: Cut
# result: Agu
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 3, 7, 1]
# Typo: Replace
# result: Nfvgrbes
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 1, 0, 8, 7]
# Typo: Replace
# result: tzpcembyo
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 0, 4]
# Typo: Cut
# result: ri
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 2, 3]
# Typo: Cut
# result: Ap
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 0, 8, 7, 3]
# Typo: Replace
# result: lekvembze
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 5, 4, 0]
# Typo: Replace
# result: naniboy
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0]
# Typo: Cut
# result: un
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 0, 3, 1, 5]
# Typo: Cut
# result: pebr
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 1, 5]
# Typo: Cut
# result: gus
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 1, 4, 5]
# Typo: Cut
# result: Jnu
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3, 0]
# Typo: Replace
# result: pprjl
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 0, 2]
# Typo: Cut
# result: pi
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0]
# Typo: Cut
# result: ue
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 4, 2, 1]
# Typo: Cut
# result: Jry
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1, 0]
# Typo: Cut
# result: rl
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 1, 2, 6]
# Typo: Add
# result: NrzovgHember
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1]
# Typo: Replace
# result: Jnnu
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 0, 1]
# Typo: Replace
# result: zsril
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 1, 4, 5]
# Typo: Cut
# result: Juy
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 5, 0]
# Typo: Add
# result: OAungutst
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 4, 1, 7, 8]
# Typo: Add
# result: Sqepthezlmober
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 0, 5, 2]
# Typo: Replace
# result: fahunvy
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 5, 0]
# Typo: Replace
# result: xugyst
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 6, 2, 5]
# Typo: Add
# result: JaNntEuaMry
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 4, 6, 1]
# Typo: Cut
# result: Jnr
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 1, 5, 3, 8]
# Typo: Add
# result: SzeVptZdXember
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 3]
# Typo: Add
# result: JjuMne
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 2, 4, 3, 5]
# Typo: Add
# result: SeJOplrtembEer
#
#
#
#
# Percentage==> 0.6
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 0, 3, 6]
# Typo: Replace
# result: dynwarm
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 1, 5, 3]
# Typo: Cut
# result: Ag
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 2, 1, 6]
# Typo: Replace
# result: Jchwari
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 5, 7, 6, 2]
# Typo: Cut
# result: oem
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1, 2]
# Typo: Cut
# result: Al
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 3, 1]
# Typo: Add
# result: AFpijril
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2]
# Typo: Add
# result: Juynbe
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 7, 1, 0, 5]
# Typo: Add
# result: ENOovUembzrer
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 2, 4, 6]
# Typo: Replace
# ...
# result:
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 3, 0, 4, 5, 1, 6]
# Typo: Add
# result: hjNoADQeSvember
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 2, 0, 4, 5, 6]
# Typo: Add
# result: kJRILZoanuary
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 0, 3, 2, 4]
# Typo: Add
# result: lASfmlpril
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3, 4, 2, 0]
# Typo: Cut
# result:
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 0, 3, 2, 4]
# Typo: Add
# result: bAglVtpril
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 7, 0, 2, 3, 8, 1, 6]
# Typo: Cut
# result: m
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0, 3, 1]
# Typo: Cut
# result:
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 0, 1, 3, 2]
# Typo: Cut
# result:
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 2, 4, 1, 5]
# Typo: Add
# result: QAAKuNRgust
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 7, 3, 1, 0, 4, 6, 5]
# Typo: Cut
# result: p
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 3, 1, 0, 4]
# Typo: Replace
# result: plgfun
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 4, 7, 0, 8, 2, 3, 6]
# Typo: Cut
# result: e
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 8, 6, 4, 7, 5, 1, 3]
# Typo: Add
# result: SAeJzpWTteTGmbrer
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 3, 0, 2]
# Typo: Add
# result: nJrXuKne
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 3, 4, 2, 1]
# Typo: Cut
# result: A
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 2, 5, 4, 0, 3]
# Typo: Cut
# result: a
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1, 0, 2]
# Typo: Cut
# result:
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [4, 0, 3, 1, 5]
# Typo: Add
# result: hmAumeguJst
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1, 0, 2]
# Typo: Cut
# result:
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 4, 1, 2, 5]
# Typo: Add
# result: sqCAuQgSust
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 1, 4, 3, 0]
# Typo: Cut
# result:
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 4, 1, 2, 3]
# Typo: Replace
# result: qyxzc
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0, 2, 1]
# Typo: Cut
# result:
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 4, 1, 5, 3]
# Typo: Add
# result: AuufYghmust
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 3, 0, 2]
# Typo: Add
# result: pJVzufne
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 4, 5, 2, 1]
# Typo: Replace
# result: fdxuaa
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 0, 3, 2, 4]
# Typo: Cut
# result: u
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 2, 4, 3, 6, 5, 7]
# Typo: Add
# result: NCHCoDxdovember
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 0, 2, 3, 5, 6, 7, 8]
# Typo: Replace
# result: gewclksbp
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 0, 3, 2, 4]
# Typo: Cut
# result:
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 2, 3, 1, 0]
# Typo: Replace
# result: odiyj
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 2, 3, 1, 6, 7, 4, 5]
# Typo: Cut
# result: S
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 0, 2, 6, 3, 5]
# Typo: Cut
# result: a
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 3, 1, 2]
# Typo: Cut
# result:
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 5, 4, 8, 6, 1, 2, 7]
# Typo: Replace
# result: Sqlhcetmr
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 3, 0, 1, 4]
# Typo: Add
# result: fhAusdIgust
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 5, 0, 2, 6, 1]
# Typo: Cut
# result: u
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3, 2, 4, 0]
# Typo: Cut
# result:
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 0, 1, 2, 4]
# Typo: Add
# result: KZqARpryil
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1, 2, 0]
# Typo: Replace
# result: hvgl
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 5, 3, 2, 4, 1]
# Typo: Cut
# result: J
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 1, 4, 3, 0]
# Typo: Replace
# result: ndgmv
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 6, 0, 2, 3, 7, 4]
# Typo: Replace
# result: motiiavm
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 2, 3, 0]
# Typo: Cut
# result:
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 2, 4, 0, 1]
# Typo: Replace
# result: duubn
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 0, 2, 4, 3, 6]
# Typo: Add
# result: IJNQagvnuafry
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 0, 2, 3, 4]
# Typo: Cut
# result: t
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [1, 6, 4, 2, 8, 5, 7, 3]
# Typo: Replace
# result: Sesmatqsg
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 0, 3, 4, 6, 2]
# Typo: Replace
# result: rixkwrm
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 3, 1, 5, 4]
# Typo: Cut
# result: g
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 6, 5, 1, 2, 4]
# Typo: Replace
# result: pffumts
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 2, 0, 3, 5, 4]
# Typo: Cut
# result: y
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 4, 8, 1, 5, 6, 7, 0]
# Typo: Replace
# result: wopawaajz
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 1, 3, 0]
# Typo: Cut
# result:
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 3, 5, 6, 4, 7, 0, 8]
# Typo: Add
# result: kSenUPpljEptember
#
#
#
#
# Percentage==> 1
# row: 0
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 5, 6, 3, 2, 0, 1]
# Typo: Add
# result: WfJaonTuUEOary
#
#
# row: 1
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 5, 0, 4, 2, 1]
# Typo: Cut
# result:
#
#
# row: 2
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 0, 6, 2, 3, 4, 1]
# Typo: Cut
# result:
#
#
# row: 3
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 5, 7, 2, 6, 0, 3, 4]
# Typo: Add
# result: bNVHFVoveJBmBber
#
#
# row: 4
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 0, 2, 4, 1]
# Typo: Cut
# result:
#
#
# row: 5
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 0, 1, 4, 3]
# Typo: Add
# result: jIAqpIOril
#
#
# row: 6
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 1, 0, 3]
# Typo: Replace
# result: hykb
#
#
# row: 7
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 4, 1, 5, 6, 2, 7, 3]
# Typo: Replace
# result: qrogkexu
#
#
# row: 8
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 4, 5, 2, 1, 6, 0]
# Typo: Replace
# result: ozwbhig
#
#
# row: 9
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 5, 1, 4, 2, 3]
# Typo: Replace
# result: jefitf
#
#
# row: 10
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 5, 3, 7, 4, 0, 2, 1]
# Typo: Add
# result: FnNVovegemqwbEer
#
#
# row: 11
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0, 1, 3]
# Typo: Add
# result: wZJmuJne
#
#
# row: 12
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 2, 1, 0]
# Typo: Cut
# result:
#
#
# row: 13
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 2, 5, 7, 1, 6, 3, 8, 0]
# Typo: Cut
# result:
#
#
# row: 14
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 3, 1, 2, 5, 4]
# Typo: Cut
# result:
#
#
# row: 15
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 4, 0, 1, 2]
# Typo: Cut
# result:
#
#
# row: 16
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 5, 0, 4, 3, 1]
# Typo: Cut
# result:
#
#
# row: 17
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 2, 0, 3]
# Typo: Replace
# result: ccdx
#
#
# row: 18
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 2, 4, 5, 3, 1, 7, 0]
# Typo: Add
# result: MNbojBvglDembFer
#
#
# row: 19
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 3, 7, 5, 0, 4, 2, 1]
# Typo: Replace
# result: cidrghkb
#
#
# row: 20
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 1, 0, 3]
# Typo: Cut
# result:
#
#
# row: 21
# MONTH: November
# LENGTH: 8
# POSITIONS: [5, 4, 6, 7, 2, 3, 1, 0]
# Typo: Replace
# result: zkyohnsq
#
#
# row: 22
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 4, 6, 5, 0, 3, 2]
# Typo: Replace
# result: ifjfmor
#
#
# row: 23
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 4, 3, 0, 7, 5, 2, 6]
# Typo: Replace
# result: gofbftnn
#
#
# row: 24
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 3, 0, 5, 6, 4, 2]
# Typo: Add
# result: HJrLaJpernuary
#
#
# row: 25
# MONTH: September
# LENGTH: 9
# POSITIONS: [4, 8, 3, 0, 1, 2, 6, 7, 5]
# Typo: Cut
# result:
#
#
# row: 26
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 3, 4, 1, 2]
# Typo: Replace
# result: nggkh
#
#
# row: 27
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 2, 4, 3, 0]
# Typo: Cut
# result:
#
#
# row: 28
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3, 0, 4, 2]
# Typo: Replace
# result: yltla
#
#
# row: 29
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 6, 5, 0, 1, 2, 4]
# Typo: Add
# result: mkhJyanJueaVry
#
#
# row: 30
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 3, 6, 0, 1, 5, 2]
# Typo: Replace
# result: wzkzfon
#
#
# row: 31
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 5, 0, 6, 2, 1, 7, 4]
# Typo: Add
# result: fFNNaovWveKnmber
#
#
# row: 32
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0, 1, 2]
# Typo: Replace
# result: jmqo
#
#
# row: 33
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 3, 2, 1, 0, 5, 4]
# Typo: Cut
# result:
#
#
# row: 34
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 1, 5, 7, 0, 3, 6, 4, 8]
# Typo: Cut
# result:
#
#
# row: 35
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 7, 6, 2, 3, 5, 0, 1]
# Typo: Replace
# result: mzdvqcwf
#
#
# row: 36
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0, 1, 3]
# Typo: Cut
# result:
#
#
# row: 37
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 2, 3, 4, 1]
# Typo: Add
# result: DaABArpril
#
#
# row: 38
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 1, 2, 4, 3, 0]
# Typo: Replace
# result: ttmpav
#
#
# row: 39
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 4, 0, 5, 1, 6, 3]
# Typo: Add
# result: DVJyaNnOwxuary
#
#
# row: 40
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 7, 4, 5, 2, 0, 1, 3, 6]
# Typo: Replace
# result: theiowacg
#
#
# row: 41
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 1, 7, 5, 6, 0, 2, 3]
# Typo: Replace
# result: muszoyal
#
#
# row: 42
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 0, 4, 3, 2, 5]
# Typo: Add
# result: MAGgyXujgust
#
#
# row: 43
# MONTH: January
# LENGTH: 7
# POSITIONS: [3, 1, 6, 5, 2, 0, 4]
# Typo: Replace
# result: xzjrphj
#
#
# row: 44
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 3, 0, 4, 6, 5, 1]
# Typo: Cut
# result:
#
#
# row: 45
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 1, 5, 3, 2, 4]
# Typo: Replace
# result: xlingl
#
#
# row: 46
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 4, 3, 0, 2]
# Typo: Cut
# result:
#
#
# row: 47
# MONTH: November
# LENGTH: 8
# POSITIONS: [0, 6, 7, 3, 5, 4, 2, 1]
# Typo: Add
# result: sJNRoOYvNemuCber
#
#
# row: 48
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 6, 5, 2, 4, 1, 3, 0]
# Typo: Cut
# result:
#
#
# row: 49
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 2, 7, 4, 3, 1, 5, 0]
# Typo: Cut
# result:
#
#
# row: 50
# MONTH: November
# LENGTH: 8
# POSITIONS: [3, 0, 4, 1, 5, 2, 6, 7]
# Typo: Replace
# result: vddhjcdl
#
#
# row: 51
# MONTH: November
# LENGTH: 8
# POSITIONS: [2, 4, 6, 3, 5, 7, 1, 0]
# Typo: Cut
# result:
#
#
# row: 52
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 0, 1, 2]
# Typo: Cut
# result:
#
#
# row: 53
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0, 1, 3]
# Typo: Cut
# result:
#
#
# row: 54
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 2, 4, 7, 6, 8, 1, 0, 5]
# Typo: Replace
# result: zcwbcislj
#
#
# row: 55
# MONTH: November
# LENGTH: 8
# POSITIONS: [7, 2, 3, 6, 4, 1, 0, 5]
# Typo: Add
# result: ONPoUDeHveTmbeVr
#
#
# row: 56
# MONTH: September
# LENGTH: 9
# POSITIONS: [8, 0, 2, 3, 6, 7, 4, 1, 5]
# Typo: Replace
# result: wjilbzabk
#
#
# row: 57
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 6, 7, 3, 2, 4, 0, 1, 8]
# Typo: Add
# result: IPSetpLqDteggEmber
#
#
# row: 58
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 3, 5, 8, 0, 4, 1, 7, 2]
# Typo: Cut
# result:
#
#
# row: 59
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 6, 2, 4, 8, 7, 5, 1, 3]
# Typo: Add
# result: KCSHEeONptyevrmber
#
#
# row: 60
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 2, 5, 0, 4, 1]
# Typo: Cut
# result:
#
#
# row: 61
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 2, 6, 3, 0, 7, 5, 4]
# Typo: Cut
# result:
#
#
# row: 62
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 0, 8, 7, 1, 2, 4, 5, 6]
# Typo: Add
# result: kusSQmUepptewmdber
#
#
# row: 63
# MONTH: August
# LENGTH: 6
# POSITIONS: [5, 4, 0, 2, 1, 3]
# Typo: Cut
# result:
#
#
# row: 64
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 1, 3, 0]
# Typo: Replace
# result: mlgd
#
#
# row: 65
# MONTH: November
# LENGTH: 8
# POSITIONS: [1, 2, 3, 5, 0, 7, 4, 6]
# Typo: Cut
# result:
#
#
# row: 66
# MONTH: January
# LENGTH: 7
# POSITIONS: [5, 4, 3, 6, 0, 1, 2]
# Typo: Cut
# result:
#
#
# row: 67
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 0, 4, 1, 2]
# Typo: Cut
# result:
#
#
# row: 68
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 3, 1, 2, 4]
# Typo: Cut
# result:
#
#
# row: 69
# MONTH: April
# LENGTH: 5
# POSITIONS: [4, 2, 0, 1, 3]
# Typo: Replace
# result: nlrku
#
#
# row: 70
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 2, 6, 1, 8, 7, 5, 4, 0]
# Typo: Replace
# result: pbvvrsphu
#
#
# row: 71
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 2, 1, 3]
# Typo: Add
# result: kVJDeune
#
#
# row: 72
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 0, 2, 3, 4]
# Typo: Replace
# result: krxpf
#
#
# row: 73
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 4, 3, 2, 5, 1]
# Typo: Cut
# result:
#
#
# row: 74
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 0, 7, 3, 5, 1, 6, 4, 8]
# Typo: Add
# result: rpSeonKYUypteimber
#
#
# row: 75
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 0, 4, 5, 1, 3]
# Typo: Replace
# result: nhhigo
#
#
# row: 76
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 4, 0, 6, 2, 7, 1, 8, 3]
# Typo: Cut
# result:
#
#
# row: 77
# MONTH: September
# LENGTH: 9
# POSITIONS: [5, 2, 4, 3, 6, 7, 1, 0, 8]
# Typo: Replace
# result: zouojlqxf
#
#
# row: 78
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 0, 3, 1]
# Typo: Replace
# result: asyi
#
#
# row: 79
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 3, 5, 2, 4, 1]
# Typo: Cut
# result:
#
#
# row: 80
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 3, 4, 1, 2, 0, 5]
# Typo: Cut
# result:
#
#
# row: 81
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 1, 3, 0]
# Typo: Add
# result: uJAuKzne
#
#
# row: 82
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 4, 2, 0, 5, 1]
# Typo: Cut
# result:
#
#
# row: 83
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 3, 2, 1]
# Typo: Replace
# result: rifr
#
#
# row: 84
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 5, 1, 2, 3, 4]
# Typo: Add
# result: pmnoAAuguTst
#
#
# row: 85
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 2, 4, 1, 0]
# Typo: Replace
# result: upghu
#
#
# row: 86
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 3, 2, 1, 4]
# Typo: Add
# result: WfALDpdril
#
#
# row: 87
# MONTH: June
# LENGTH: 4
# POSITIONS: [2, 1, 0, 3]
# Typo: Replace
# result: phrr
#
#
# row: 88
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 2, 0, 3, 4, 5]
# Typo: Add
# result: zAEONvFugust
#
#
# row: 89
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 3, 0, 2]
# Typo: Cut
# result:
#
#
# row: 90
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 2, 4, 3, 1, 5]
# Typo: Cut
# result:
#
#
# row: 91
# MONTH: August
# LENGTH: 6
# POSITIONS: [2, 0, 5, 1, 4, 3]
# Typo: Add
# result: NJAWuAkguust
#
#
# row: 92
# MONTH: November
# LENGTH: 8
# POSITIONS: [4, 2, 5, 7, 0, 1, 6, 3]
# Typo: Cut
# result:
#
#
# row: 93
# MONTH: September
# LENGTH: 9
# POSITIONS: [3, 6, 8, 7, 5, 1, 4, 0, 2]
# Typo: Replace
# result: yznknedgt
#
#
# row: 94
# MONTH: April
# LENGTH: 5
# POSITIONS: [3, 1, 4, 2, 0]
# Typo: Cut
# result:
#
#
# row: 95
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 3, 0, 1, 4]
# Typo: Add
# result: HeApycpril
#
#
# row: 96
# MONTH: September
# LENGTH: 9
# POSITIONS: [0, 7, 4, 5, 3, 2, 6, 1, 8]
# Typo: Add
# result: ODSoeqpFUNXtemUber
#
#
# row: 97
# MONTH: January
# LENGTH: 7
# POSITIONS: [6, 5, 4, 2, 0, 3, 1]
# Typo: Cut
# result:
#
#
# row: 98
# MONTH: June
# LENGTH: 4
# POSITIONS: [1, 0, 3, 2]
# Typo: Cut
# result:
#
#
# row: 99
# MONTH: September
# LENGTH: 9
# POSITIONS: [7, 2, 4, 8, 0, 1, 6, 3, 5]
# Typo: Add
# result: poSFeTYpCXtemhbaer
#
#
# row: 100
# MONTH: August
# LENGTH: 6
# POSITIONS: [0, 4, 1, 2, 5, 3]
# Typo: Add
# result: cihTAuQgCust
#
#
# row: 101
# MONTH: January
# LENGTH: 7
# POSITIONS: [2, 4, 5, 6, 1, 3, 0]
# Typo: Replace
# result: gagakiy
#
#
# row: 102
# MONTH: April
# LENGTH: 5
# POSITIONS: [2, 0, 1, 4, 3]
# Typo: Cut
# result:
#
#
# row: 103
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 3, 2, 0, 4]
# Typo: Replace
# result: tdcjv
#
#
# row: 104
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1, 2, 0]
# Typo: Cut
# result:
#
#
# row: 105
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 2, 1, 3, 5, 6, 4]
# Typo: Add
# result: uCJUPnARanuary
#
#
# row: 106
# MONTH: April
# LENGTH: 5
# POSITIONS: [0, 4, 1, 3, 2]
# Typo: Cut
# result:
#
#
# row: 107
# MONTH: November
# LENGTH: 8
# POSITIONS: [6, 1, 5, 7, 0, 2, 4, 3]
# Typo: Cut
# result:
#
#
# row: 108
# MONTH: June
# LENGTH: 4
# POSITIONS: [3, 1, 2, 0]
# Typo: Replace
# result: famo
#
#
# row: 109
# MONTH: April
# LENGTH: 5
# POSITIONS: [1, 4, 3, 2, 0]
# Typo: Replace
# result: gjpmt
#
#
# row: 110
# MONTH: January
# LENGTH: 7
# POSITIONS: [0, 3, 2, 4, 6, 1, 5]
# Typo: Cut
# result:
#
#
# row: 111
# MONTH: August
# LENGTH: 6
# POSITIONS: [1, 2, 3, 5, 4, 0]
# Typo: Cut
# result:
#
#
# row: 112
# MONTH: September
# LENGTH: 9
# POSITIONS: [1, 4, 0, 5, 2, 3, 6, 7, 8]
# Typo: Add
# result: dSaNlepMrpTvtember
#
#
# row: 113
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 4, 0, 2, 6, 5, 3]
# Typo: Add
# result: wJzsMapnCguary
#
#
# row: 114
# MONTH: August
# LENGTH: 6
# POSITIONS: [3, 2, 1, 4, 5, 0]
# Typo: Add
# result: nAcuPEtgKust
#
#
# row: 115
# MONTH: January
# LENGTH: 7
# POSITIONS: [1, 0, 6, 3, 5, 4, 2]
# Typo: Cut
# result:
#
#
# row: 116
# MONTH: January
# LENGTH: 7
# POSITIONS: [4, 5, 3, 0, 2, 6, 1]
# Typo: Cut
# result:
#
#
# row: 117
# MONTH: September
# LENGTH: 9
# POSITIONS: [2, 1, 0, 6, 7, 5, 4, 3, 8]
# Typo: Add
# result: DSlteNcHvpeBtember
#
#
# row: 118
# MONTH: June
# LENGTH: 4
# POSITIONS: [0, 3, 2, 1]
# Typo: Replace
# result: htmy
#
#
# row: 119
# MONTH: September
# LENGTH: 9
# POSITIONS: [6, 5, 0, 8, 7, 1, 3, 4, 2]
# Typo: Add
# result: DJwSLEepteBJmSZber

# %%
df.to_csv('E_D_NoisySet')
