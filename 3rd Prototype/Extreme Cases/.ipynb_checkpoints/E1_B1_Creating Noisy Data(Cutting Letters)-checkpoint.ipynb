# %%
import pandas as pd
import numpy as np
import random
import string
from decimal import Decimal , ROUND_HALF_UP

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Import dataset
df=pd.read_csv('E_Initial.csv')
df=df.drop('Unnamed: 0' , 1)
df
# Out:
#     STD_Months
# 0      January
# 1       August
# 2      January
# 3     November
# 4        April
# 5        April
# 6         June
# 7     November
# 8      January
# 9       August
# 10    November
# 11        June
# 12        June
# 13   September
# 14      August
# 15       April
# 16      August
# 17        June
# 18    November
# 19    November
# 20        June
# 21    November
# 22     January
# 23    November
# 24     January
# 25   September
# 26       April
# 27       April
# 28       April
# 29     January
# ..         ...
# 90      August
# 91      August
# 92    November
# 93   September
# 94       April
# 95       April
# 96   September
# 97     January
# 98        June
# 99   September
# 100     August
# 101    January
# 102      April
# 103      April
# 104       June
# 105    January
# 106      April
# 107   November
# 108       June
# 109      April
# 110    January
# 111     August
# 112  September
# 113    January
# 114     August
# 115    January
# 116    January
# 117  September
# 118       June
# 119  September
#
# [120 rows x 1 columns]

# %%
Values = df['STD_Months'].value_counts()
print(Values)
Values.plot.barh()
plt.show()
# Out:
# September    20
# June         20
# November     20
# April        20
# January      20
# August       20
# Name: STD_Months, dtype: int64

# %%
#Creating 10% to 100% noise
p = [.1 , .2 , .3 , .4 , .5 , 0.6 , 0.7]

for pi in p:    
    #Extract the column's indices [0,1,...,99]
    df[str(pi)+'_TypoB'] = ''
    ix = [(row) for row in range(df['STD_Months'].shape[0])]
    
    for row in ix:
        print("row:" ,row)
        indxs = [i for i , _ in enumerate(df['STD_Months'].iat[row])]
        month = df['STD_Months'].iat[row]
        print(month)
        print ('Index:',indxs)
        length = len(indxs)
        print('length:' , length)
        
        #Coputing the no of letters to cut , considering the length of month
        letters = Decimal(str(length*pi)).quantize(Decimal("1"), rounding=ROUND_HALF_UP)
        print('letters to cut:' , letters)
        
        if letters>0:
            #Selecting random positions for cutting the letters
            positions = random.sample(range(length) , int(letters))
            print('selected positions:' , positions)
            
            for ind in positions:
                """ Replacing chosen letters with '-' """
                month = month[:ind] + "-" + month[ind+1:]
            #Cutting chosen letters                     
            month = month.replace("-" , "")    
            df[str(pi)+'_TypoB'].iat[row] = month
            print('Result:' , month)
            print('\n')
            
        else:
            print('No change!')
            df[str(pi)+'_TypoB'].iat[row] = df['STD_Months'].iat[row]
            print('\n')
# Out:
# row: 0
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 1
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 2
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 3
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Novemer
#
#
# row: 4
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 6
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [6]
# Result: Novembr
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 9
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 10
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 11
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 12
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 13
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [4]
# Result: Septmber
#
#
# row: 14
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 15
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 16
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 17
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 18
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 19
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Noveber
#
#
# row: 20
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 21
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [7]
# Result: Novembe
#
#
# row: 22
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 23
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Novemer
#
#
# row: 24
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 25
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [1]
# Result: Sptember
#
#
# row: 26
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 27
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 28
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 29
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 31
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Novemer
#
#
# row: 32
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 33
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 34
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [6]
# Result: Septemer
#
#
# row: 35
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Noveber
#
#
# row: 36
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 37
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 38
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 39
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [2]
# Result: Jauary
#
#
# row: 40
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [5]
# Result: Septeber
#
#
# row: 41
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 42
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 43
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 44
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [2]
# Result: Jauary
#
#
# row: 45
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 46
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 47
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [5]
# Result: Novemer
#
#
# row: 48
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 49
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [7]
# Result: Novembe
#
#
# row: 50
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 51
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [7]
# Result: Novembe
#
#
# row: 52
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 53
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 54
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [1]
# Result: Sptember
#
#
# row: 55
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Noveber
#
#
# row: 56
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [6]
# Result: Septemer
#
#
# row: 57
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [6]
# Result: Septemer
#
#
# row: 58
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [5]
# Result: Septeber
#
#
# row: 59
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [7]
# Result: Septembr
#
#
# row: 60
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 61
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [2]
# Result: Noember
#
#
# row: 62
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [1]
# Result: Sptember
#
#
# row: 63
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 64
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 65
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [0]
# Result: ovember
#
#
# row: 66
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [3]
# Result: Janary
#
#
# row: 67
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 68
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 69
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 70
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [1]
# Result: Sptember
#
#
# row: 71
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 72
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 73
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 74
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [2]
# Result: Setember
#
#
# row: 75
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 76
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [8]
# Result: Septembe
#
#
# row: 77
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [7]
# Result: Septembr
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 79
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 80
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 81
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 82
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 83
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 84
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 85
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 87
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 88
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 89
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 90
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 91
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 92
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [6]
# Result: Novembr
#
#
# row: 93
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [6]
# Result: Septemer
#
#
# row: 94
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 95
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 96
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [0]
# Result: eptember
#
#
# row: 97
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 98
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 99
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [3]
# Result: Sepember
#
#
# row: 100
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 101
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 103
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 104
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 105
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 106
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 107
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 1
# selected positions: [4]
# Result: Noveber
#
#
# row: 108
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 109
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 110
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 111
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 112
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [6]
# Result: Septemer
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 114
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 115
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [2]
# Result: Jauary
#
#
# row: 116
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [4]
# Result: Septmber
#
#
# row: 118
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 0
# No change!
#
#
# row: 119
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 1
# selected positions: [2]
# Result: Setember
#
#
# row: 0
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 1
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 2
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 3
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 4]
# Result: Novebe
#
#
# row: 4
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 6
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 3]
# Result: Nvmber
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Janury
#
#
# row: 9
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 10
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 7]
# Result: Noveme
#
#
# row: 11
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 12
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 13
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [7, 2]
# Result: Setembr
#
#
# row: 14
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 15
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 16
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 17
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 18
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 5]
# Result: Noveme
#
#
# row: 19
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 5]
# Result: Noemer
#
#
# row: 20
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 21
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 5]
# Result: Novmer
#
#
# row: 22
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [2]
# Result: Jauary
#
#
# row: 23
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 2]
# Result: Noembr
#
#
# row: 24
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Janury
#
#
# row: 25
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 2]
# Result: Stember
#
#
# row: 26
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 27
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 28
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 29
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 31
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 5]
# Result: Noveer
#
#
# row: 32
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 33
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 34
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [3, 6]
# Result: Sepemer
#
#
# row: 35
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 7]
# Result: Noveme
#
#
# row: 36
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 37
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 38
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [3]
# Result: Augst
#
#
# row: 39
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [4]
# Result: Janury
#
#
# row: 40
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [4, 8]
# Result: Septmbe
#
#
# row: 41
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 6]
# Result: Noembr
#
#
# row: 42
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [3]
# Result: Augst
#
#
# row: 43
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [1]
# Result: Jnuary
#
#
# row: 44
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 45
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 46
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 47
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 2]
# Result: Noembr
#
#
# row: 48
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 4]
# Result: Noveer
#
#
# row: 49
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 3]
# Result: Nvmber
#
#
# row: 50
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 6]
# Result: Nvembr
#
#
# row: 51
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 7]
# Result: Novemb
#
#
# row: 52
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 53
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 54
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [2, 6]
# Result: Setemer
#
#
# row: 55
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 0]
# Result: oveber
#
#
# row: 56
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [8, 1]
# Result: Sptembe
#
#
# row: 57
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [2, 1]
# Result: Stember
#
#
# row: 58
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [8, 1]
# Result: Sptembe
#
#
# row: 59
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 6]
# Result: Sptemer
#
#
# row: 60
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 61
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 1]
# Result: Nvembr
#
#
# row: 62
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [6, 7]
# Result: Septemr
#
#
# row: 63
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [3]
# Result: Augst
#
#
# row: 64
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 65
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 3]
# Result: Nvmber
#
#
# row: 66
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 67
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 68
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 69
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 70
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 8]
# Result: Sptembe
#
#
# row: 71
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 72
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [1]
# Result: Aril
#
#
# row: 73
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 74
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 7]
# Result: Sptembr
#
#
# row: 75
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [4]
# Result: Augut
#
#
# row: 76
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [4, 2]
# Result: Setmber
#
#
# row: 77
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [1, 2]
# Result: Stember
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 79
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [0]
# Result: ugust
#
#
# row: 80
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 81
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 82
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 83
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 84
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [5]
# Result: Augus
#
#
# row: 85
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [0]
# Result: pril
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 87
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 88
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 89
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 90
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [3]
# Result: Augst
#
#
# row: 91
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 92
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 6]
# Result: Novemr
#
#
# row: 93
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [0, 3]
# Result: epember
#
#
# row: 94
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 95
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 96
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [6, 7]
# Result: Septemr
#
#
# row: 97
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [5]
# Result: Januay
#
#
# row: 98
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 99
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [5, 4]
# Result: Septber
#
#
# row: 100
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [2]
# Result: Auust
#
#
# row: 101
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [2]
# Result: Jauary
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [4]
# Result: Apri
#
#
# row: 103
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 104
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 105
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [2]
# Result: Jauary
#
#
# row: 106
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [3]
# Result: Aprl
#
#
# row: 107
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 0]
# Result: ovmber
#
#
# row: 108
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 109
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 1
# selected positions: [2]
# Result: Apil
#
#
# row: 110
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 111
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 112
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [3, 6]
# Result: Sepemer
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 114
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 1
# selected positions: [1]
# Result: Agust
#
#
# row: 115
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [6]
# Result: Januar
#
#
# row: 116
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 1
# selected positions: [0]
# Result: anuary
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [2, 0]
# Result: etember
#
#
# row: 118
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 119
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 2
# selected positions: [6, 4]
# Result: Septmer
#
#
# row: 0
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [4, 3]
# Result: Janry
#
#
# row: 1
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [5, 2]
# Result: Auus
#
#
# row: 2
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [5, 1]
# Result: Jnuay
#
#
# row: 3
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 2]
# Result: Nember
#
#
# row: 4
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 2]
# Result: Api
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 4]
# Result: pri
#
#
# row: 6
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 6]
# Result: Novemb
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 5]
# Result: Janua
#
#
# row: 9
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 1]
# Result: Aust
#
#
# row: 10
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 1]
# Result: Nveber
#
#
# row: 11
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 12
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 13
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [1, 3, 6]
# Result: Spemer
#
#
# row: 14
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 1]
# Result: Aust
#
#
# row: 15
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 2]
# Result: Ail
#
#
# row: 16
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [3, 4]
# Result: Augt
#
#
# row: 17
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 18
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 1]
# Result: Nvemer
#
#
# row: 19
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 6]
# Result: Novemr
#
#
# row: 20
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 21
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [0, 1]
# Result: vember
#
#
# row: 22
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [1, 5]
# Result: Jnuay
#
#
# row: 23
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 1]
# Result: Nvemer
#
#
# row: 24
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [1, 5]
# Result: Jnuay
#
#
# row: 25
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [3, 0, 6]
# Result: epemer
#
#
# row: 26
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 3]
# Result: Apr
#
#
# row: 27
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 4]
# Result: Apr
#
#
# row: 28
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 1]
# Result: Ail
#
#
# row: 29
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [2, 5]
# Result: Jauay
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [0, 6]
# Result: anuar
#
#
# row: 31
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 1]
# Result: Nveber
#
#
# row: 32
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 33
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [6, 3]
# Result: Janar
#
#
# row: 34
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [1, 8, 3]
# Result: Spembe
#
#
# row: 35
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [4, 1]
# Result: Nveber
#
#
# row: 36
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 37
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 1]
# Result: Ari
#
#
# row: 38
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 3]
# Result: Agst
#
#
# row: 39
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [1, 5]
# Result: Jnuay
#
#
# row: 40
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [1, 8, 5]
# Result: Sptebe
#
#
# row: 41
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 7]
# Result: Nvembe
#
#
# row: 42
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [0, 5]
# Result: ugus
#
#
# row: 43
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [0, 3]
# Result: anary
#
#
# row: 44
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [0, 1]
# Result: nuary
#
#
# row: 45
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 1]
# Result: Aust
#
#
# row: 46
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 4]
# Result: Api
#
#
# row: 47
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 1]
# Result: Nvembe
#
#
# row: 48
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 2]
# Result: Noemer
#
#
# row: 49
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 1]
# Result: Nvemer
#
#
# row: 50
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [2, 5]
# Result: Noemer
#
#
# row: 51
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [5, 6]
# Result: Novemr
#
#
# row: 52
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [2]
# Result: Jue
#
#
# row: 53
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 54
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [1, 2, 6]
# Result: Stemer
#
#
# row: 55
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 3]
# Result: Novmbr
#
#
# row: 56
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [4, 5, 0]
# Result: eptber
#
#
# row: 57
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [5, 7, 1]
# Result: Sptebr
#
#
# row: 58
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [8, 6, 4]
# Result: Septme
#
#
# row: 59
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [7, 4, 6]
# Result: Septmr
#
#
# row: 60
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [0, 3]
# Result: ugst
#
#
# row: 61
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [3, 5]
# Result: Novmer
#
#
# row: 62
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [7, 3, 4]
# Result: Sepmbr
#
#
# row: 63
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 3]
# Result: Aust
#
#
# row: 64
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 65
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [1, 0]
# Result: vember
#
#
# row: 66
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [3, 1]
# Result: Jnary
#
#
# row: 67
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 1]
# Result: Ari
#
#
# row: 68
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 3]
# Result: prl
#
#
# row: 69
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 1]
# Result: ril
#
#
# row: 70
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [0, 8, 7]
# Result: eptemb
#
#
# row: 71
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 72
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 2]
# Result: Api
#
#
# row: 73
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 5]
# Result: Agus
#
#
# row: 74
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [6, 4, 7]
# Result: Septmr
#
#
# row: 75
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [0, 2]
# Result: uust
#
#
# row: 76
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [8, 2, 1]
# Result: Stembe
#
#
# row: 77
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [3, 7, 2]
# Result: Seembr
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 79
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [3, 4]
# Result: Augt
#
#
# row: 80
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [4, 2]
# Result: Jaury
#
#
# row: 81
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 82
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 5]
# Result: Agus
#
#
# row: 83
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 84
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 0]
# Result: ugut
#
#
# row: 85
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 4]
# Result: Api
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 0]
# Result: ril
#
#
# row: 87
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 88
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [5, 4]
# Result: Augu
#
#
# row: 89
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 90
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 5]
# Result: Auus
#
#
# row: 91
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 5]
# Result: Agus
#
#
# row: 92
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [6, 1]
# Result: Nvembr
#
#
# row: 93
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [5, 6, 7]
# Result: Septer
#
#
# row: 94
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 0]
# Result: pil
#
#
# row: 95
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 4]
# Result: Apr
#
#
# row: 96
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [8, 4, 1]
# Result: Sptmbe
#
#
# row: 97
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [5, 2]
# Result: Jauay
#
#
# row: 98
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 99
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [6, 1, 3]
# Result: Spemer
#
#
# row: 100
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 2]
# Result: Auut
#
#
# row: 101
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [2, 5]
# Result: Jauay
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 2]
# Result: Ail
#
#
# row: 103
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 3]
# Result: Apr
#
#
# row: 104
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [3]
# Result: Jun
#
#
# row: 105
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [1, 5]
# Result: Jnuay
#
#
# row: 106
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 2]
# Result: Ail
#
#
# row: 107
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 2
# selected positions: [7, 3]
# Result: Novmbe
#
#
# row: 108
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [0]
# Result: une
#
#
# row: 109
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [4, 1]
# Result: Ari
#
#
# row: 110
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [4, 1]
# Result: Jnury
#
#
# row: 111
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 2]
# Result: Auut
#
#
# row: 112
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [2, 4, 5]
# Result: Setber
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [5, 2]
# Result: Jauay
#
#
# row: 114
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [3, 1]
# Result: Agst
#
#
# row: 115
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [4, 2]
# Result: Jaury
#
#
# row: 116
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 2
# selected positions: [2, 3]
# Result: Jaary
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [3, 8, 4]
# Result: Sepmbe
#
#
# row: 118
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 1
# selected positions: [1]
# Result: Jne
#
#
# row: 119
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 3
# selected positions: [0, 4, 8]
# Result: eptmbe
#
#
# row: 0
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [4, 6, 5]
# Result: Janu
#
#
# row: 1
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [0, 3]
# Result: ugst
#
#
# row: 2
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [2, 6, 4]
# Result: Jaur
#
#
# row: 3
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [1, 6, 3]
# Result: Nvmbr
#
#
# row: 4
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 1]
# Result: Ail
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 3]
# Result: Arl
#
#
# row: 6
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 0]
# Result: ne
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [5, 3, 2]
# Result: Nomer
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [2, 0, 5]
# Result: auay
#
#
# row: 9
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 3]
# Result: Augt
#
#
# row: 10
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [3, 0, 4]
# Result: ovber
#
#
# row: 11
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 2]
# Result: Je
#
#
# row: 12
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [0, 2]
# Result: ue
#
#
# row: 13
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [5, 4, 7, 2]
# Result: Setbr
#
#
# row: 14
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [5, 1]
# Result: Agus
#
#
# row: 15
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 0]
# Result: ril
#
#
# row: 16
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [2, 3]
# Result: Aust
#
#
# row: 17
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 3]
# Result: Ju
#
#
# row: 18
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [1, 5, 2]
# Result: Nemer
#
#
# row: 19
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [4, 3, 5]
# Result: Nover
#
#
# row: 20
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 0]
# Result: ne
#
#
# row: 21
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [3, 0, 1]
# Result: vmber
#
#
# row: 22
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [6, 0, 2]
# Result: auar
#
#
# row: 23
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 4, 1]
# Result: Neber
#
#
# row: 24
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [4, 1, 6]
# Result: Jnur
#
#
# row: 25
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [5, 7, 0, 4]
# Result: eptbr
#
#
# row: 26
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 4]
# Result: pri
#
#
# row: 27
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [3, 4]
# Result: Apr
#
#
# row: 28
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 0]
# Result: ril
#
#
# row: 29
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [1, 4, 3]
# Result: Jnry
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [1, 5, 2]
# Result: Juay
#
#
# row: 31
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 0, 3]
# Result: omber
#
#
# row: 32
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 3]
# Result: Jn
#
#
# row: 33
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [2, 4, 0]
# Result: aury
#
#
# row: 34
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [3, 1, 2, 4]
# Result: Smber
#
#
# row: 35
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [0, 5, 1]
# Result: vemer
#
#
# row: 36
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [3, 0]
# Result: un
#
#
# row: 37
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 4]
# Result: Api
#
#
# row: 38
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 0]
# Result: ugut
#
#
# row: 39
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [2, 0, 4]
# Result: aury
#
#
# row: 40
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [8, 1, 3, 5]
# Result: Spebe
#
#
# row: 41
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [1, 0, 2]
# Result: ember
#
#
# row: 42
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [4, 0]
# Result: ugut
#
#
# row: 43
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [2, 4, 5]
# Result: Jauy
#
#
# row: 44
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [0, 5, 3]
# Result: anay
#
#
# row: 45
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [1, 4]
# Result: Agut
#
#
# row: 46
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [1, 0]
# Result: ril
#
#
# row: 47
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [7, 1, 3]
# Result: Nvmbe
#
#
# row: 48
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [0, 3, 5]
# Result: ovmer
#
#
# row: 49
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [6, 0, 7]
# Result: ovemb
#
#
# row: 50
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [5, 6, 0]
# Result: ovemr
#
#
# row: 51
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [0, 2, 7]
# Result: oembe
#
#
# row: 52
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [0, 1]
# Result: ne
#
#
# row: 53
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 3]
# Result: Ju
#
#
# row: 54
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [7, 2, 5, 4]
# Result: Setbr
#
#
# row: 55
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 6, 4]
# Result: Noebr
#
#
# row: 56
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [4, 2, 7, 1]
# Result: Stmbr
#
#
# row: 57
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [8, 6, 7, 2]
# Result: Setem
#
#
# row: 58
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [7, 0, 2, 5]
# Result: etebr
#
#
# row: 59
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [8, 5, 3, 2]
# Result: Seebe
#
#
# row: 60
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [5, 0]
# Result: ugus
#
#
# row: 61
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [2, 4, 1]
# Result: Neber
#
#
# row: 62
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 4
# selected positions: [6, 2, 3, 4]
# Result: Semer
#
#
# row: 63
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 2
# selected positions: [3, 0]
# Result: ugst
#
#
# row: 64
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 3]
# Result: Ju
#
#
# row: 65
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 3
# selected positions: [3, 1, 2]
# Result: Nmber
#
#
# row: 66
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 3
# selected positions: [4, 3, 0]
# Result: anry
#
#
# row: 67
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [2, 4]
# Result: Api
#
#
# row: 68
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 2
# selected positions: [0, 2]
# Result: pil
#
#
# row: 69
# April
# ...
# letters to cut: 4
# selected positions: [0, 5, 1, 4]
# Result: nuy
#
#
# row: 106
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 3
# selected positions: [4, 2, 1]
# Result: Ai
#
#
# row: 107
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 5
# selected positions: [4, 0, 5, 2, 7]
# Result: oee
#
#
# row: 108
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [1, 0]
# Result: ne
#
#
# row: 109
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 3
# selected positions: [2, 1, 3]
# Result: Al
#
#
# row: 110
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 4
# selected positions: [2, 1, 6, 5]
# Result: Jua
#
#
# row: 111
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [4, 1, 0, 5]
# Result: gu
#
#
# row: 112
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [2, 8, 5, 7, 1]
# Result: Steb
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 4
# selected positions: [0, 2, 4, 6]
# Result: aur
#
#
# row: 114
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 1, 4, 0]
# Result: gt
#
#
# row: 115
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 4
# selected positions: [1, 2, 0, 3]
# Result: ary
#
#
# row: 116
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 4
# selected positions: [3, 5, 1, 2]
# Result: Jay
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [4, 5, 2, 3, 8]
# Result: Sebe
#
#
# row: 118
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 2
# selected positions: [2, 0]
# Result: ue
#
#
# row: 119
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 5
# selected positions: [3, 8, 0, 2, 5]
# Result: eebe
#
#
# row: 0
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [3, 2, 6, 1, 5]
# Result: Ja
#
#
# row: 1
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 4, 5, 3]
# Result: Au
#
#
# row: 2
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [5, 4, 6, 2, 3]
# Result: Ja
#
#
# row: 3
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 3, 1, 6, 5, 4]
# Result: Nr
#
#
# row: 4
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 4, 3, 2]
# Result: A
#
#
# row: 5
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 2, 1, 0]
# Result: l
#
#
# row: 6
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 2, 0]
# Result: e
#
#
# row: 7
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [7, 6, 3, 0, 2, 4]
# Result: ob
#
#
# row: 8
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 5, 6, 3, 0]
# Result: aa
#
#
# row: 9
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 4, 0, 1]
# Result: ut
#
#
# row: 10
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [6, 5, 2, 4, 0, 7]
# Result: oe
#
#
# row: 11
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 3, 2]
# Result: u
#
#
# row: 12
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 1]
# Result: e
#
#
# row: 13
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [1, 8, 0, 3, 6, 5]
# Result: pee
#
#
# row: 14
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [0, 5, 2, 4]
# Result: uu
#
#
# row: 15
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 4, 3, 0]
# Result: p
#
#
# row: 16
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [1, 4, 0, 5]
# Result: gu
#
#
# row: 17
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 1, 2]
# Result: J
#
#
# row: 18
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 1, 5, 2, 3, 0]
# Result: er
#
#
# row: 19
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [3, 2, 0, 5, 6, 7]
# Result: om
#
#
# row: 20
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 2, 3]
# Result: u
#
#
# row: 21
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 4, 5, 0, 7, 3]
# Result: ve
#
#
# row: 22
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [0, 6, 3, 4, 1]
# Result: nr
#
#
# row: 23
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [7, 3, 2, 0, 6, 4]
# Result: ob
#
#
# row: 24
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [6, 5, 4, 3, 1]
# Result: Jn
#
#
# row: 25
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [7, 8, 0, 4, 6, 1]
# Result: ptm
#
#
# row: 26
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 0, 3, 1]
# Result: l
#
#
# row: 27
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [4, 2, 3, 1]
# Result: A
#
#
# row: 28
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 1, 4, 0]
# Result: i
#
#
# row: 29
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [4, 3, 1, 5, 2]
# Result: Jy
#
#
# row: 30
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [0, 3, 5, 6, 1]
# Result: na
#
#
# row: 31
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 4, 2, 0, 7, 3]
# Result: be
#
#
# row: 32
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 1, 3]
# Result: J
#
#
# row: 33
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [4, 6, 3, 1, 2]
# Result: Jr
#
#
# row: 34
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [6, 4, 7, 5, 1, 8]
# Result: Spt
#
#
# row: 35
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 7, 0, 1, 6, 5]
# Result: ve
#
#
# row: 36
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 2, 0]
# Result: u
#
#
# row: 37
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 2, 1, 3]
# Result: l
#
#
# row: 38
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 5, 4, 3]
# Result: Au
#
#
# row: 39
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 3, 5, 6, 1]
# Result: Ja
#
#
# row: 40
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [4, 1, 6, 0, 2, 7]
# Result: tmr
#
#
# row: 41
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 4, 6, 2, 7, 3]
# Result: No
#
#
# row: 42
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [0, 5, 3, 4]
# Result: ug
#
#
# row: 43
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 5, 0, 6, 4]
# Result: nu
#
#
# row: 44
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [5, 2, 4, 3, 1]
# Result: Jy
#
#
# row: 45
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 1, 5, 2]
# Result: As
#
#
# row: 46
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 2, 0, 4]
# Result: i
#
#
# row: 47
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 1, 5, 6, 3, 0]
# Result: mr
#
#
# row: 48
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [2, 5, 1, 0, 4, 3]
# Result: er
#
#
# row: 49
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 2, 7, 3, 0, 5]
# Result: me
#
#
# row: 50
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [0, 5, 4, 7, 2, 1]
# Result: ee
#
#
# row: 51
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [4, 5, 6, 7, 2, 0]
# Result: oe
#
#
# row: 52
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 3, 0]
# Result: n
#
#
# row: 53
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 1, 2]
# Result: e
#
#
# row: 54
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [6, 1, 7, 8, 3, 4]
# Result: Spm
#
#
# row: 55
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [7, 6, 4, 5, 0, 1]
# Result: ve
#
#
# row: 56
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [2, 8, 7, 6, 4, 5]
# Result: Set
#
#
# row: 57
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [2, 8, 3, 0, 1, 6]
# Result: eme
#
#
# row: 58
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [0, 7, 2, 3, 4, 5]
# Result: ebr
#
#
# row: 59
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [0, 2, 3, 6, 1, 8]
# Result: eme
#
#
# row: 60
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [4, 5, 3, 2]
# Result: Au
#
#
# row: 61
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 0, 4, 6, 1, 7]
# Result: ve
#
#
# row: 62
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [6, 4, 0, 7, 5, 1]
# Result: ptr
#
#
# row: 63
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [5, 3, 2, 0]
# Result: us
#
#
# row: 64
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 1]
# Result: e
#
#
# row: 65
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 0, 2, 6, 3, 5]
# Result: mr
#
#
# row: 66
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 4, 0, 1, 5]
# Result: uy
#
#
# row: 67
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [4, 3, 1, 0]
# Result: r
#
#
# row: 68
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 4, 1, 3]
# Result: r
#
#
# row: 69
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 4, 3, 2]
# Result: A
#
#
# row: 70
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [2, 7, 6, 8, 1, 4]
# Result: Stm
#
#
# row: 71
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 0, 3]
# Result: n
#
#
# row: 72
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [2, 0, 4, 3]
# Result: p
#
#
# row: 73
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [1, 0, 2, 3]
# Result: st
#
#
# row: 74
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [8, 6, 7, 0, 4, 3]
# Result: epm
#
#
# row: 75
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [5, 3, 0, 2]
# Result: us
#
#
# row: 76
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [1, 3, 5, 8, 0, 7]
# Result: peb
#
#
# row: 77
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [1, 4, 8, 2, 6, 0]
# Result: tme
#
#
# row: 78
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 2, 1]
# Result: J
#
#
# row: 79
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [4, 5, 2, 0]
# Result: uu
#
#
# row: 80
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [5, 0, 4, 2, 1]
# Result: uy
#
#
# row: 81
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 0, 1]
# Result: n
#
#
# row: 82
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [5, 3, 1, 2]
# Result: As
#
#
# row: 83
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 3, 2]
# Result: u
#
#
# row: 84
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 5, 3, 0]
# Result: us
#
#
# row: 85
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 1, 2, 4]
# Result: i
#
#
# row: 86
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [4, 0, 1, 2]
# Result: i
#
#
# row: 87
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 1, 3]
# Result: J
#
#
# row: 88
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 4, 1, 0]
# Result: ut
#
#
# row: 89
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [3, 1, 0]
# Result: n
#
#
# row: 90
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [0, 5, 2, 3]
# Result: us
#
#
# row: 91
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [1, 0, 5, 4]
# Result: gu
#
#
# row: 92
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [5, 0, 6, 2, 3, 4]
# Result: or
#
#
# row: 93
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [8, 7, 3, 2, 4, 1]
# Result: Smb
#
#
# row: 94
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 0, 4, 2]
# Result: i
#
#
# row: 95
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 3, 4, 0]
# Result: r
#
#
# row: 96
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [2, 7, 4, 3, 1, 6]
# Result: Smr
#
#
# row: 97
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 5, 4, 3, 1]
# Result: Jy
#
#
# row: 98
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 0, 1]
# Result: e
#
#
# row: 99
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [8, 2, 4, 7, 1, 6]
# Result: Stm
#
#
# row: 100
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [2, 3, 0, 1]
# Result: st
#
#
# row: 101
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 5, 4, 2, 3]
# Result: Jy
#
#
# row: 102
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [1, 2, 3, 0]
# Result: l
#
#
# row: 103
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [3, 1, 0, 2]
# Result: l
#
#
# row: 104
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [0, 1, 2]
# Result: e
#
#
# row: 105
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [1, 3, 4, 0, 6]
# Result: nr
#
#
# row: 106
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 1, 3, 2]
# Result: l
#
#
# row: 107
# November
# Index: [0, 1, 2, 3, 4, 5, 6, 7]
# length: 8
# letters to cut: 6
# selected positions: [1, 6, 4, 7, 2, 5]
# Result: Ne
#
#
# row: 108
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [2, 3, 1]
# Result: J
#
#
# row: 109
# April
# Index: [0, 1, 2, 3, 4]
# length: 5
# letters to cut: 4
# selected positions: [0, 4, 2, 3]
# Result: p
#
#
# row: 110
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [5, 4, 2, 1, 6]
# Result: Ju
#
#
# row: 111
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [4, 2, 0, 1]
# Result: ut
#
#
# row: 112
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [0, 1, 6, 4, 7, 5]
# Result: ptr
#
#
# row: 113
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [6, 3, 4, 0, 2]
# Result: ar
#
#
# row: 114
# August
# Index: [0, 1, 2, 3, 4, 5]
# length: 6
# letters to cut: 4
# selected positions: [3, 2, 0, 1]
# Result: st
#
#
# row: 115
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [4, 0, 1, 5, 3]
# Result: ny
#
#
# row: 116
# January
# Index: [0, 1, 2, 3, 4, 5, 6]
# length: 7
# letters to cut: 5
# selected positions: [2, 0, 1, 3, 6]
# Result: ar
#
#
# row: 117
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [1, 2, 6, 7, 4, 8]
# Result: Stm
#
#
# row: 118
# June
# Index: [0, 1, 2, 3]
# length: 4
# letters to cut: 3
# selected positions: [1, 3, 0]
# Result: n
#
#
# row: 119
# September
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# length: 9
# letters to cut: 6
# selected positions: [3, 4, 0, 6, 8, 1]
# Result: pme

# %%
df.to_csv('E_B_NoisySet')
